# %%
import requests

# %%
url = 'https://www.bok.or.kr/portal/singl/newsData/listCont.do?'
params = {
    'pageIndex': 1,
    'targetDepth': 4,
    'menuNo': 200789,
    'syncMenuChekKey': 1,
    'depthSubMain': '',
    'subMainAt': '',
    'searchCnd': 1,
    'searchKwd': '',
    'depth2': 200038,
    'depth3': 201154,
    'depth4': 200789,
}
res = requests.get(url, params=params)
res.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup as bs

# %%
soup = bs(res.text)
soup.prettify
# Out:
# <bound method Tag.prettify of <html><head><script>
# //@@@1@@@
#   $(function() {
#     if (false){
#       $('.date-set').show();
#     }else{
#       $('.date-set').hide();
#     }
#
#     $(".select1 select").on("change", function(){
#       var result = $(".select1 option:selected").val()
#       if(result == 5){
#         $('.date-set').show();
#       }else{
#         $('.date-set').hide();
#       }
#     });
#   });
#
#   // 콘텐츠 서비스
#   $(function () {
#     // 달력 언어설정
#     if (typeof $.fn.datepicker != 'undefined') {
#       $.fn.datepicker.dates.ko = {
#         days: ['일요일', '월요일', '화요일', '수요일', '목요일', '금요일', '토요일'],
#         daysShort: ['일', '월', '화', '수', '목', '금', '토'],
#         daysMin: ['일', '월', '화', '수', '목', '금', '토'],
#         months: ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'],
#         monthsShort: ['1월', '2월', '3월', '4월', '5월', '6월', '7월', '8월', '9월', '10월', '11월', '12월'],
#         today: '오늘',
#         clear: '삭제',
#         format: 'yyyy-mm-dd',
#         titleFormat: 'yyyy년mm월',
#         weekStart: 0,
#       };
#     }
#     inputdate = $('input.sdate,input.edate,input.date');
#     inputdate.attr('autocomplete', 'off');
#     function formatDate(num) {
#       if (!num) return "";
#       var formatNum = '';
#       // 공백제거
#       num = num.replace(/\s/gi, "");
#       try {
#         if (num.length == 8) {
#           formatNum = num.replace(/(\d{4})(\d{2})(\d{2})/, '$1-$2-$3');
#         }
#       } catch (e) {
#         formatNum = num;
#         console.log(e);
#       }
#       formatNum = formatNum == '' ? num : formatNum
#       return formatNum;
#     }
#     // 날짜형태 변환
#     $(inputdate).on('keyup', function (event) {
#       if(event.target.value.indexOf('-') === -1 && event.target.value.length == 8){
#         event.target.value = formatDate(event.target.value)
#       }
#     });
#     // 달력
#     if (typeof $.fn.datepicker != 'undefined') {
#       inputdate
#               .datepicker({
#                 format: 'yyyy-mm-dd',
#                 language: 'ko',
#                 todayHighlight: true,
#                 autoclose: true,
#                 templates: {
#                   leftArrow: '<i class=datepicker-prev role=img aria-label=이전></i>',
#                   rightArrow: '<i class=datepicker-next role=img aria-label=다음></i>'
#                 }
#               })
#               .attr('placeholder', '연도 - 월 - 일')
#       $('.month')
#               .datepicker({
#                 format: 'yyyy-mm',
#                 language: 'ko',
#                 todayHighlight: true,
#                 autoclose: true,
#                 templates: {
#                   leftArrow: '<i class=datepicker-prev role=img aria-label=이전></i>',
#                   rightArrow: '<i class=datepicker-next role=img aria-label=다음></i>'
#                 },
#                 startView: 2,
#                 minViewMode: 1
#               })
#               .attr('placeholder', '연도 - 월')
#               .attr('autocomplete', 'off')
#     }
#     $('input.sdate').attr('title', '검색기간 시작일 연도 - 월 - 일');
#     $('input.edate').attr('title', '검색기간 종료일 연도 - 월 - 일');
#     $('input.month').attr('title', '검색기간 연도 - 월');
#     $('input.smonth').attr('title', '검색기간 시작월 연도 - 월');
#     $('input.emonth').attr('title', '검색기간 종료월 연도 - 월');
#     $('input.date').each(function () {
#       var title = $(this).attr('title') + ' 연도 - 월 - 일'
#       $(this).attr('title', title)
#     });
#     // 달력
#     if(!isMobile() && typeof $.fn.datepicker != "undefined"){
#       $('input.sdate,input.edate,input.date')
#               .datepicker({
#                 format: "yyyy-mm-dd",
#                 language: "ko",
#                 todayHighlight: true,
#                 autoclose:true
#               })
#               .attr('placeholder','연도 - 월 - 일')
#     }
#
#     // 탭 활성화
#     $(".js-tab button").on('click', function(){
#       var $parent = $(this).closest(".js-tab");
#       var index = $(this).parent().index();
#       $(this)
#               .attr("aria-pressed", true).parent().addClass("on").attr('title','선택됨')
#               .siblings().removeClass("on").find("button").attr("aria-pressed", false).removeAttr('title')
#       $parent
#               .siblings(".tab-content").find(".con").hide().eq(index).show();
#     });
#
#     // 탭 활성화
#     $('.tab-list').each(function (index, element) {
#       $(this).find('button')
#               .on('click', function (e) {
#                 e.preventDefault();
#                 $(this).attr('aria-selected', true).attr('title','선택됨').siblings().attr('aria-selected', false).removeAttr('title')
#                 _id = $(this).attr('id')
#                 $('[aria-labelledby="' + _id + '"]').show().siblings().hide()
#               })
#     });
#
#
#     // 이미지맵 반응형
#     if(typeof $.fn.rwdImageMaps != "undefined"){
#       $('img[usemap]').rwdImageMaps();
#     }
#     // 한글파라미터 인코딩
#     $('.linkencode area').each(function (e) {
#       _href = encodeURIComponent($(this).attr('href').split('searchWrd=')[1])
#       $(this).attr('href', $(this).attr('href').split('searchWrd=')[0] + 'searchWrd=' + _href)
#     })
#   });
#
# </script>
# </head><body><div class="sh-BxSet">
# <p class="count-total">총 <strong>530</strong>건의 게시물이 있습니다.</p>
# <div class="sh-select">
# <div class="select-set select1">
# <select id="date" name="date" title="개월 선택">
# <option value="">전체 기간</option>
# <option value="1">1개월</option>
# <option value="2">3개월</option>
# <option value="3">6개월</option>
# <option value="4">1년</option>
# <option value="5">직접선택</option>
# </select>
# </div>
# <div class="date-set" style="display: none;">
# <input autocomplete="off" class="sdate" id="sdate" name="sdate" title="검색기간 시작일" type="text" value=""/>
# <span class="dash">~</span>
# <input autocomplete="off" class="edate" id="edate" name="edate" title="검색기간 종료일" type="text" value=""/>
# </div>
# <div class="select-set select2">
# <select id="sort" name="sort" title="정렬순서 선택">
# <option value="1">최신순</option>
# <option value="2">조회순</option>
# </select>
# </div>
# <div class="select-set select3">
# <select id="pageUnit" name="pageUnit" title="개수 선택">
# <option selected="selected" value="10">10개</option>
# <option value="20">20개</option>
# <option value="30">30개</option>
# <option value="40">40개</option>
# <option value="50">50개</option>
# <option value="100">100개</option>
# </select>
# </div>
# <button aria-label="검색" class="submit" id="confirmBtn" onclick="return false;" type="button"></button>
# </div>
# </div>
# <div class="bd-line">
# <ul>
# <li class="bbsRowCls">
# <span class="i">
# <span class="t1">
#
#
# 				의사록
#
# 				</span>
# </span>
# <span class="dataInfo">
# <span class="depart"><span class="sr-only">담당부서</span>의사팀</span>
# <span class="hits"><span class="sr-only">조회수</span>294</span>
# <span class="date"><span class="sr-only">등록일</span>2024.08.06</span>
# </span>
# <div class="set">
# <a class="title" href="/portal/bbs/B0000245/view.do?nttId=10086296&amp;searchCnd=1&amp;searchKwd=&amp;depth2=200038&amp;depth3=201154&amp;depth4=200789&amp;depth=200789&amp;pageUnit=10&amp;pageIndex=1&amp;programType=newsData&amp;menuNo=200789&amp;oldMenuNo=200789">
# <!-- <span class="ti-announcement"><span class="sr-only">공지사항</span></span>   -->
#               금융통화위원회 의사록(2024년도 제14차)(2024.7.18)
#             </a>
# </div>
# </li>
# <li class="bbsRowCls">
# <span class="i">
# <span class="t1">
#
#
# 				의사록
#
# 				</span>
# </span>
# <span class="dataInfo">
# <span class="depart"><span class="sr-only">담당부서</span>의사팀</span>
# <span class="hits"><span class="sr-only">조회수</span>627</span>
# <span class="date"><span class="sr-only">등록일</span>2024.07.30</span>
# </span>
# <div class="set">
# <a class="title" href="/portal/bbs/B0000245/view.do?nttId=10086177&amp;searchCnd=1&amp;searchKwd=&amp;depth2=200038&amp;depth3=201154&amp;depth4=200789&amp;depth=200789&amp;pageUnit=10&amp;pageIndex=1&amp;programType=newsData&amp;menuNo=200789&amp;oldMenuNo=200789">
# <!-- <span class="ti-announcement"><span class="sr-only">공지사항</span></span>   -->
#               금융통화위원회 의사록(2024년도 제13차)(2024.7.11)
#             </a>
# </div>
# </li>
# <li class="bbsRowCls">
# <span class="i">
# <span class="t1">
#
#
# 				의사록
#
# 				</span>
# </span>
# <span class="dataInfo">
# <span class="depart"><span class="sr-only">담당부서</span>의사팀</span>
# <span class="hits"><span class="sr-only">조회수</span>271</span>
# <span class="date"><span class="sr-only">등록일</span>2024.07.16</span>
# </span>
# <div class="set">
# <a class="title" href="/portal/bbs/B0000245/view.do?nttId=10085855&amp;searchCnd=1&amp;searchKwd=&amp;depth2=200038&amp;depth3=201154&amp;depth4=200789&amp;depth=200789&amp;pageUnit=10&amp;pageIndex=1&amp;programType=newsData&amp;menuNo=200789&amp;oldMenuNo=200789">
# <!-- <span class="ti-announcement"><span class="sr-only">공지사항</span></span>   -->
#               금융통화위원회 의사록(2024년도 제12차)(2024.6.26)
#             </a>
# </div>
# </li>
# <li class="bbsRowCls">
# <span class="i">
# <span class="t1">
#
#
# 				의사록
#
# 				</span>
# </span>
# <span class="dataInfo">
# <span class="depart"><span class="sr-only">담당부서</span>의사팀</span>
# <span class="hits"><span class="sr-only">조회수</span>482</span>
# <span class="date"><span class="sr-only">등록일</span>2024.07.02</span>
# </span>
# <div class="set">
# <a class="title" href="/portal/bbs/B0000245/view.do?nttId=10085535&amp;searchCnd=1&amp;searchKwd=&amp;depth2=200038&amp;depth3=201154&amp;depth4=200789&amp;depth=200789&amp;pageUnit=10&amp;pageIndex=1&amp;programType=newsData&amp;menuNo=200789&amp;oldMenuNo=200789">
# <!-- <span class="ti-announcement"><span class="sr-only">공지사항</span></span>   -->
#               금융통화위원회 의사록(2024년도 제11차)(2024.6.13)
#             </a>
# </div>
# </li>
# <li class="bbsRowCls">
# <span class="i">
# <span class="t1">
#
#
# 				의사록
#
# 				</span>
# </span>
# <span class="dataInfo">
# <span class="depart"><span class="sr-only">담당부서</span>의사팀</span>
# <span class="hits"><span class="sr-only">조회수</span>2551</span>
# <span class="date"><span class="sr-only">등록일</span>2024.06.11</span>
# </span>
# <div class="set">
# <a class="title" href="/portal/bbs/B0000245/view.do?nttId=10084604&amp;searchCnd=1&amp;searchKwd=&amp;depth2=200038&amp;depth3=201154&amp;depth4=200789&amp;depth=200789&amp;pageUnit=10&amp;pageIndex=1&amp;programType=newsData&amp;menuNo=200789&amp;oldMenuNo=200789">
# <!-- <span class="ti-announcement"><span class="sr-only">공지사항</span></span>   -->
#               금융통화위원회 의사록(2024년도 제10차)(2024.5.23)
#             </a>
# </div>
# </li>
# <li class="bbsRowCls">
# <span class="i">
# <span class="t1">
#
#
# 				의사록
#
# 				</span>
# </span>
# <span class="dataInfo">
# <span class="depart"><span class="sr-only">담당부서</span>의사팀</span>
# <span class="hits"><span class="sr-only">조회수</span>4362</span>
# <span class="date"><span class="sr-only">등록일</span>2024.05.28</span>
# </span>
# <div class="set">
# <a class="title" href="/portal/bbs/B0000245/view.do?nttId=10084317&amp;searchCnd=1&amp;searchKwd=&amp;depth2=200038&amp;depth3=201154&amp;depth4=200789&amp;depth=200789&amp;pageUnit=10&amp;pageIndex=1&amp;programType=newsData&amp;menuNo=200789&amp;oldMenuNo=200789">
# <!-- <span class="ti-announcement"><span class="sr-only">공지사항</span></span>   -->
#               금융통화위원회 의사록(2024년도 제9차)(2024.5.9)
#             </a>
# </div>
# </li>
# <li class="bbsRowCls">
# <span class="i">
# <span class="t1">
#
#
# 				의사록
#
# 				</span>
# </span>
# <span class="dataInfo">
# <span class="depart"><span class="sr-only">담당부서</span>의사팀</span>
# <span class="hits"><span class="sr-only">조회수</span>9787</span>
# <span class="date"><span class="sr-only">등록일</span>2024.04.30</span>
# </span>
# <div class="set">
# <a class="title" href="/portal/bbs/B0000245/view.do?nttId=10083904&amp;searchCnd=1&amp;searchKwd=&amp;depth2=200038&amp;depth3=201154&amp;depth4=200789&amp;depth=200789&amp;pageUnit=10&amp;pageIndex=1&amp;programType=newsData&amp;menuNo=200789&amp;oldMenuNo=200789">
# <!-- <span class="ti-announcement"><span class="sr-only">공지사항</span></span>   -->
#               금융통화위원회 의사록(2024년도 제7차)(2024.4.12)
#             </a>
# </div>
# </li>
# <li class="bbsRowCls">
# <span class="i">
# <span class="t1">
#
#
# 				의사록
#
# 				</span>
# </span>
# <span class="dataInfo">
# <span class="depart"><span class="sr-only">담당부서</span>의사팀</span>
# <span class="hits"><span class="sr-only">조회수</span>11292</span>
# <span class="date"><span class="sr-only">등록일</span>2024.04.16</span>
# </span>
# <div class="set">
# <a class="title" href="/portal/bbs/B0000245/view.do?nttId=10083536&amp;searchCnd=1&amp;searchKwd=&amp;depth2=200038&amp;depth3=201154&amp;depth4=200789&amp;depth=200789&amp;pageUnit=10&amp;pageIndex=1&amp;programType=newsData&amp;menuNo=200789&amp;oldMenuNo=200789">
# <!-- <span class="ti-announcement"><span class="sr-only">공지사항</span></span>   -->
#               금융통화위원회 의사록(2024년도 제6차)(2024.3.28)
#             </a>
# </div>
# </li>
# <li class="bbsRowCls">
# <span class="i">
# <span class="t1">
#
#
# 				의사록
#
# 				</span>
# </span>
# <span class="dataInfo">
# <span class="depart"><span class="sr-only">담당부서</span>의사팀</span>
# <span class="hits"><span class="sr-only">조회수</span>13182</span>
# <span class="date"><span class="sr-only">등록일</span>2024.04.02</span>
# </span>
# <div class="set">
# <a class="title" href="/portal/bbs/B0000245/view.do?nttId=10083335&amp;searchCnd=1&amp;searchKwd=&amp;depth2=200038&amp;depth3=201154&amp;depth4=200789&amp;depth=200789&amp;pageUnit=10&amp;pageIndex=1&amp;programType=newsData&amp;menuNo=200789&amp;oldMenuNo=200789">
# <!-- <span class="ti-announcement"><span class="sr-only">공지사항</span></span>   -->
#               금융통화위원회 의사록(2024년도 제5차)(2024.3.14)
#             </a>
# </div>
# </li>
# <li class="bbsRowCls">
# <span class="i">
# <span class="t1">
#
#
# 				의사록
#
# 				</span>
# </span>
# <span class="dataInfo">
# <span class="depart"><span class="sr-only">담당부서</span>의사팀</span>
# <span class="hits"><span class="sr-only">조회수</span>16229</span>
# <span class="date"><span class="sr-only">등록일</span>2024.03.12</span>
# </span>
# <div class="set">
# <a class="title" href="/portal/bbs/B0000245/view.do?nttId=10082900&amp;searchCnd=1&amp;searchKwd=&amp;depth2=200038&amp;depth3=201154&amp;depth4=200789&amp;depth=200789&amp;pageUnit=10&amp;pageIndex=1&amp;programType=newsData&amp;menuNo=200789&amp;oldMenuNo=200789">
# <!-- <span class="ti-announcement"><span class="sr-only">공지사항</span></span>   -->
#               금융통화위원회 의사록(2024년도 제4차)(2024.2.22)
#             </a>
# </div>
# </li>
# </ul>
# </div>
# <div class="paginationSet">
# <div class="paginationSet"><ul class="pagination pagination-centered"><li class="i first disabled"><span class="s"><span>처음 <span class="t">목록</span></span></span></li><li class="i prev disabled"><span class="s"><span>이전 <span class="t">목록</span></span></span></li><li class="active"><span><em title="현재목록"><span>1</span></em></span></li><li><a href="javascript:fnSearch(2)"><span>2</span></a></li><li><a href="javascript:fnSearch(3)"><span>3</span></a></li><li><a href="javascript:fnSearch(4)"><span>4</span></a></li><li><a href="javascript:fnSearch(5)"><span>5</span></a></li><li><a href="javascript:fnSearch(6)"><span>6</span></a></li><li><a href="javascript:fnSearch(7)"><span>7</span></a></li><li><a href="javascript:fnSearch(8)"><span>8</span></a></li><li><a href="javascript:fnSearch(9)"><span>9</span></a></li><li><a href="javascript:fnSearch(10)"><span>10</span></a></li><li class="i next"><a href="javascript:fnSearch(11)" title="다음 목록"><span class="s"><span>다음 <span class="t">목록</span></span></span></a></li><li class="i end"><a href="javascript:fnSearch(53)" title="마지막 목록"><span class="s"><span>끝 <span class="t">목록</span></span></span></a></li></ul></div>
# </div>
# <script>
# $(".bbsRowCls").click(function() {
# 	location.href= $(this).find("a").attr("href");
# 	return false;
# });
# </script>
# </body></html>>

# %%
lis = soup.select('li.bbsRowCls')
links = [li.select_one('a').get('href') for li in lis]
print(links)
# Out:
# ['/portal/bbs/B0000245/view.do?nttId=10086296&searchCnd=1&searchKwd=&depth2=200038&depth3=201154&depth4=200789&depth=200789&pageUnit=10&pageIndex=1&programType=newsData&menuNo=200789&oldMenuNo=200789', '/portal/bbs/B0000245/view.do?nttId=10086177&searchCnd=1&searchKwd=&depth2=200038&depth3=201154&depth4=200789&depth=200789&pageUnit=10&pageIndex=1&programType=newsData&menuNo=200789&oldMenuNo=200789', '/portal/bbs/B0000245/view.do?nttId=10085855&searchCnd=1&searchKwd=&depth2=200038&depth3=201154&depth4=200789&depth=200789&pageUnit=10&pageIndex=1&programType=newsData&menuNo=200789&oldMenuNo=200789', '/portal/bbs/B0000245/view.do?nttId=10085535&searchCnd=1&searchKwd=&depth2=200038&depth3=201154&depth4=200789&depth=200789&pageUnit=10&pageIndex=1&programType=newsData&menuNo=200789&oldMenuNo=200789', '/portal/bbs/B0000245/view.do?nttId=10084604&searchCnd=1&searchKwd=&depth2=200038&depth3=201154&depth4=200789&depth=200789&pageUnit=10&pageIndex=1&programType=newsData&menuNo=200789&oldMenuNo=200789', '/portal/bbs/B0000245/view.do?nttId=10084317&searchCnd=1&searchKwd=&depth2=200038&depth3=201154&depth4=200789&depth=200789&pageUnit=10&pageIndex=1&programType=newsData&menuNo=200789&oldMenuNo=200789', '/portal/bbs/B0000245/view.do?nttId=10083904&searchCnd=1&searchKwd=&depth2=200038&depth3=201154&depth4=200789&depth=200789&pageUnit=10&pageIndex=1&programType=newsData&menuNo=200789&oldMenuNo=200789', '/portal/bbs/B0000245/view.do?nttId=10083536&searchCnd=1&searchKwd=&depth2=200038&depth3=201154&depth4=200789&depth=200789&pageUnit=10&pageIndex=1&programType=newsData&menuNo=200789&oldMenuNo=200789', '/portal/bbs/B0000245/view.do?nttId=10083335&searchCnd=1&searchKwd=&depth2=200038&depth3=201154&depth4=200789&depth=200789&pageUnit=10&pageIndex=1&programType=newsData&menuNo=200789&oldMenuNo=200789', '/portal/bbs/B0000245/view.do?nttId=10082900&searchCnd=1&searchKwd=&depth2=200038&depth3=201154&depth4=200789&depth=200789&pageUnit=10&pageIndex=1&programType=newsData&menuNo=200789&oldMenuNo=200789']

# %%
pdf_url = 'https://www.bok.or.kr' + links[0]
res = requests.get(pdf_url)
res.status_code
# Out:
# 200

# %%
soup = bs(res.text)

# %%
pdfs = soup.select('a.file')
a = 'https://www.bok.or.kr' + pdfs[1].get('href')
a
# Out:
# 'https://www.bok.or.kr/fileSrc/portal/8426eabe5ead44c4a1cfe6eccbc8ed3d/2/0cdeedba97704d7d93f46249561cc473.pdf'

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from scrapy_selenium import SeleniumRequest
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from PyPDF2 import PdfReader
from io import BytesIO
import os
import time
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 5
#       3 from selenium.webdriver.common.by import By
#       4 from webdriver_manager.chrome import ChromeDriverManager
# ----> 5 from scrapy_selenium import SeleniumRequest
#       6 from selenium.webdriver.common.by import By
#       7 from selenium.webdriver.support import expected_conditions as EC
#
# ModuleNotFoundError: No module named 'scrapy_selenium'

# %%
call_url = 'https://www.korcham.net/nCham/Service/EconBrief/appl/ProspectBoardList.asp'
params = {
    'board_type': 1,
    'pageno': 1,
    'daybt': 'OldNow',
    'm_OldDate': 20140811,
    'm_NowDate': 20240811
}
call_res = requests.get(call_url, params=params)
call_res.encoding = 'euc-kr'
call_res.status_code
# Out:
# 200

# %%
call_soup = bs(call_res.text)
call_soup
# Out:
# <!DOCTYPE html>
# <html class="ko" lang="ko">
# <head>
# <!-- head area -->
# <meta charset="utf-8"/> <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/> <title>코참넷</title> <script type="application/ld+json">
# {
#  "@context": "http://schema.org",
#  "@type": "Organization",
#  "name": "대한상공회의소",
#  "url": "https://www.korcham.net",
#  "sameAs": [
#    "https://www.youtube.com/channel/UCtsmQ4ln18jB-rtyGQD6yXw"
#  ]
# }
# </script> <!-- 페이지 로딩 form element styling plugin 으로 인해 화면 가림 end --> <!--<link rel="shortcut icon" href="favicon.ico">--> <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js"></script> <script>window.jQuery || document.write(unescape('%3Cscript src="//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js"%3E%3C/script%3E'))</script> <script src="//ajax.googleapis.com/ajax/libs/jqueryui/1.11.2/jquery-ui.min.js"></script> <link href="//fonts.googleapis.com/earlyaccess/nanumgothic.css" rel="stylesheet"/> <link href="/nCham/Service/css/style_font.css" rel="stylesheet"/> <link href="//ajax.googleapis.com/ajax/libs/jqueryui/1.11.2/themes/smoothness/jquery-ui.css" rel="stylesheet"/> <script src="/nCham/Service/js/jquery.mCustomScrollbar.concat.min.js"></script> <script src="/nCham/Service/js/jquery.cookie.js"></script> <link href="/nCham/Service/css/icon.css" rel="stylesheet"/> <link href="/nCham/Service/css/style.css" rel="stylesheet"/> <link href="/nCham/Service/css/form.css" rel="stylesheet"/> <link href="/nCham/Service/css/jquery.mCustomScrollbar.css" rel="stylesheet"/> <script src="/nCham/Service/js/modernizr.js"></script> <script src="/nCham/Service/js/jquery.selectric.js"></script> <script src="/nCham/Service/js/jquery-filestyle.min.js"></script> <script src="/nCham/Service/js/common.js"></script> <script src="/nCham/Service/js/jquery.bxslider.js"></script> <script src="/nCham/Service/js/subpage.js"></script> <script type="text/javascript">
# 		$(document).ready(function() {
# 			$(document).on("click",function(e) {
# 				if($(e.target).parents(".scd_detail").size() == 0) { //셀렉트박스 닫기
# 					$(".scd_detail").hide();
# 				}
# 			});
# 			$("nav.tabsite a.more").parent("li").removeClass("open");
# 			$("nav.tabsite div.more-cont").removeClass("open");
# 			// 상단 더보기
# 			$("nav.tabsite a.more").on("click", function(e) {
# 				 $("nav.tabsite a.more").parent("li").toggleClass("open");
# 				 $("nav.tabsite div.more-cont").toggleClass("open");
# 			});
# 			$("nav.tabsite a.more-cont-close").on("click", function(e) {
# 				$("nav.tabsite a.more").parent("li").toggleClass("open");
# 				$("nav.tabsite div.more-cont").toggleClass("open");
# 			});
# 			// 셀렉트박스 styling
# 			$('select').selectric({responsive:true ,expandToItemText:true, disableOnMobile:false, openOnHover:true});
# 				// 우측 퀵메뉴.. 메인에서는 실행할 필요없음
# 			$(window).scroll(function() {
# 				rightScroller();
# 			});
# 			// 파일 박스
# 			$(":file").jfilestyle({buttonText: "파일첨부" , size:$(this).width()});
# 			// 최상단 메뉴 온오프
# 			$(".menuwrap nav > ul").hover(function(e) {
# 				e.preventDefault();
# 				$(".menuwrap").css({background:'rgba(255,255,255,0)'});
# 				$(".menuwrap").css({border:'0px'});
# 				$(".menuwrap nav > ul").toggleClass("open");
# 				$(this).find("img").toggle();
# 			},function(e) {
# 			    e.preventDefault();
# 			    $(".menuwrap nav > ul").removeClass("open");
# 				$(this).find("img").toggle();
# 			} );
# 		// 최초 로드시 서브메뉴의 높이를 각각 맞춰야한다.
# 		$submh = 0;
# 		$("header div.menu ul.subm").each(function() {
# 			if($submh < $(this).outerHeight(true)) {
# 				$submh = $(this).outerHeight(true);
# 			}
# 		});
#
# 		$("header div.menu ul.subm").height($submh);
# 		$("header div.menu ul.subm").mouseenter(function() {
# 			$(this).addClass("curr");
# 		}).mouseleave(function() {
# 			$(this).removeClass("curr");
# 		});
# 		$main_curr = "" ;
# 		$main_banner_slider =$(".main_banner ul").bxSlider({
# 			slideWidth:334,
# 			minSlides:3,
# 			maxSlides:6,
# 			moveSlides: 1,
# 			sliderMargin:0,
# 			pager:false,controls:true,infiniteLoop:false ,
# 			useCSS:false ,
# 			onSliderLoad : function(ci) {
#
# 				$idx2 = $(".main_banner  ul li").not(".bx-clone").eq(0).index();
# 				$(".main_banner ul").find("li:lt("+($idx2)+")").find("div.desc").addClass("opa50");
# 				$(".main_banner ul li:gt("+($idx2+2)+")").find("div.desc").addClass("opa50");
# 					$(".main_banner ul li").eq($idx2).find("div.desc").removeClass("opa50");
# 				$(".main_banner ul li").eq($idx2+1).find("div.desc").removeClass("opa50");
# 				$(".main_banner ul li").eq($idx2+2).find("div.desc").removeClass("opa50");
# 			},
# 			onSlideAfter : function($se, $oi, $ni) {
# 				$idx2 = $(".main_banner  ul li").not(".bx-clone").eq($ni).index();
# 				$(".main_banner ul").find("li:lt("+($idx2)+")").find("div.desc").addClass("opa50");
# 				$(".main_banner ul li:gt("+($idx2+2)+")").find("div.desc").addClass("opa50");
#
# 				$(".main_banner ul li").eq($idx2).find("div.desc").removeClass("opa50");
# 				$(".main_banner ul li").eq($idx2+1).find("div.desc").removeClass("opa50");
# 				$(".main_banner ul li").eq($idx2+2).find("div.desc").removeClass("opa50");
#
# 			}
#
#
#
#
# 		});
# 		});
# 		function toggleFigcaption( $dir, $ci){
# 			$t = $(".main_banner ul li:not(.bx-clone)").eq($ci);
# 			$idx = $t.index();
# 			if($dir == 'prev'){
# 				$(".main_banner ul li").eq($idx-1).removeClass("left,right").addClass("left").find("div.bn_area > div").animate({width:'334px'});
# 				$(".main_banner ul li").eq($idx+2).removeClass("left,right").addClass("right").find("div.bn_area > div ").animate({width:'0'});
# 			}
# 			else {
# 				$(".main_banner ul li").eq($idx).removeClass("left,right").addClass("right").find("div.bn_area > div").animate({width:'0'});
# 				$(".main_banner ul li").eq($idx+3).removeClass("left,right").addClass("left").find("div.bn_area > div").animate({width:'334px'});
# 			}
# 		}
# 		function goHistory(){
# 		var width = 990;
# 		var left = (screen.availWidth / 2) - (width / 2) - 15;
# 		window.open("https://www.korcham.net/nCham/Service/Economy/appl/HistoryPlay.asp", "hisyoty", "scrollbars=no,resizable=no,menubar=no,left="+left+",top=97,width=950,height=545");
# 		}
# 		function mainAnimationBtn(){
# 			//show(1000);
# 			$("#main_a04")
# 				.delay(5000)
# 				.animate({top:0}, 500,'easeInQuart')
# 				.delay(1600)
# 				.animate({top:-250},500,'easeInQuart',function(){$(this).removeAttr("style");});
# 			$("#main_a01")
# 				.animate({top:0}, 500 ,'easeInQuart')
# 				.delay(1500)
# 				.animate({left:334}, 500,'easeInQuart')
# 				.delay(4500)
# 				.animate({top:-500,left:-668,width:'130%',opacity:0},500,'easeInQuart',function(){$(this).removeAttr("style");});
# 			$("#main_a02")
# 				.animate({top:0}, 500,'easeInQuart')
# 				.delay(3000)
# 				.delay(1000)
# 				.animate({top:250}, 500,'easeInQuart',function(){$(this).removeAttr("style");});
# 			$("#main_a03")
# 				.animate({top:0}, 500,'easeInQuart')
# 				.delay(3000)
# 				.animate({right:334}, 500,'easeInQuart')
# 				.delay(3000)
# 				.animate({top:-500,right:-668,width:'130%',opacity:0},500,'easeInQuart',function(){$(this).removeAttr("style");});
# 		}
# 		function mainAnimation(){
# 			if( $.cookie('msa_showon') ) return false;
# 			$("#main_a04")
# 				.delay(5000)
# 				.animate({top:0}, 500,'easeInQuart')
# 				.delay(1600)
# 				.animate({top:-250},500,'easeInQuart',function(){$(this).removeAttr("style");});
# 			$("#main_a01")
# 				.animate({top:0}, 500 ,'easeInQuart')
# 				.delay(1500)
# 				.animate({left:334}, 500,'easeInQuart')
# 				.delay(4500)
# 				.animate({top:-500,left:-668,width:'130%',opacity:0},500,'easeInQuart',function(){$(this).removeAttr("style");});
# 			$("#main_a02")
# 				.animate({top:0}, 500,'easeInQuart')
# 				.delay(3000)
# 				.delay(1000)
# 				.animate({top:250}, 500,'easeInQuart',function(){$(this).removeAttr("style");});
# 			$("#main_a03")
# 				.animate({top:0}, 500,'easeInQuart')
# 				.delay(3000)
# 				.animate({right:334}, 500,'easeInQuart')
# 				.delay(3000)
# 				.animate({top:-500,right:-668,width:'130%',opacity:0},500,'easeInQuart',function(){$(this).removeAttr("style");});
# 			$.cookie('msa_showon',true);
# 		}
# 		function goMain(){
# 		cookies = 'tab_shown=; path=/nCham/Service/Main/appl';
# 		document.cookie = cookies;
#     location.href = "/nCham/Service/Main/appl/Main.asp";
#
#
#
#
# 		}
# 		function D1select(){
# 			var D1;
# 			D1 = document.getElementById("Depth1").value;
# 			location =  D1
# 		}
# 		function D2select(){
#  		var D2;
#  		D2 = document.getElementById("Depth2").value;
#  		location = D2
# 		}
# 		function D3select(){
#  		var D3;
#  		D3 = document.getElementById("Depth3").value;
#  		location = D3
# 		}
# 		function TotSearch() {
# 			var form = document.SearchForm;
# 			var cham = document.getElementById("category");
# 			if (cham.options[cham.selectedIndex].text == "통합검색"){
# 				form.action = "/nCham/Service/Search/appl/TotalSearch.asp";
# 			}else{
# 				form.action = "/nCham/Service/Search/appl/Cham.asp";
# 			}
# 			form.submit();
# 		}
# 		function loginpgONLINEmember(nm,val,SEQ_NO_D010){
# 			var nowpage = location.href;
# 			if(window.confirm('본 세미나는 상공회의소 회원사 전용 서비스 입니다.\n회원사 여부를 확인하시기 바랍니다.')) {
# 				document.chForm.action = '/nCham/Service/Member/appl/Member_Login.asp?m_LOGINAFTERURL='+escape(nowpage)+'&SEQ_NO_D010='+SEQ_NO_D010;
# 				document.chForm.submit();
# 				}
# 		}
#  </script> <script language="JavaScript">
# 		function f_login() {
# 			var nowpage = location.href;
# 			top.window.location.href='/New/Service/Main/Member/appl/login.asp?m_Act=certifi_False06&m_LOGINAFTERURL=' + escape(nowpage);
# 		}
# 		function loginpg(nm,val){
# 			var nowpage = location.href;
# 			if(window.confirm('회원전용입니다. 로그인페이지로 이동하시겠습니까?')) {
# 				document.chForm.action = '/nCham/Service/Member/appl/login.asp';
# 				document.chForm.submit();
# 				}
# 		}
# 		function loginpgBOOKZIP(nm,val){
# 			var nowpage = location.href;
# 			if(window.confirm('회원전용입니다. 로그인페이지로 이동하시겠습니까?')) {
# 				parent.document.chForm.action = '/nCham/Service/Member/appl/login.asp';
# 				parent.document.chForm.submit();
# 				}
# 		}
# 		function loginpgKCCIREPORT(nm,val){
# 			var nowpage = location.href;
# 			if(window.confirm('회원전용입니다. 로그인페이지로 이동하시겠습니까?')) {
# 				document.chForm.action = '/nCham/Service/Member/appl/login.asp?gbn=report&m_Act=certifi_False06&m_LOGINAFTERURL='+escape(nowpage);
# 				document.chForm.submit();
# 				}
# 		}
# 		function loginpgONLINE(nm,val){
# 			var nowpage = location.href;
# 			if(window.confirm('코참넷 온라인 회원 전용입니다. 로그인페이지로 이동하시겠습니까?')) {
# 				document.chForm.action = '/nCham/Service/Member/appl/login.asp?m_Act=certifi_False06&m_LOGINAFTERURL='+escape(nowpage);
# 				document.chForm.submit();
# 				}
# 		}
# 		function loginpgEVENT(nm,val){
# 			var nowpage = location.href;
# 			if(window.confirm('회원전용입니다. 로그인페이지로 이동하시겠습니까?')) {
# 				document.chForm.action = '/nCham/Service/Member/appl/login.asp?m_Act=certifi_False06&m_LOGINAFTERURL='+escape(nowpage);
# 				document.chForm.submit();
# 				}
# 		}
# 		function loginpgECONTENTS(nm,val){
# 			var nowpage = location.href;
# 			if(window.confirm('회원전용입니다. 로그인페이지로 이동하시겠습니까?')) {
# 				document.chForm.action = '/nCham/Service/Member/appl/login.asp?m_Act=certifi_False06&m_LOGINAFTERURL='+escape(nowpage);
# 				document.chForm.submit();
# 				}
# 		}
# //-->
# </script>
# <!-- head area -->
# <script language="JavaScript" type="text/JavaScript">
# 			function go_board_type(num){
# 				var  form = document.chForm;
#
# 				form.board_type.value = num;
# 				form.action = "/nCham/Service/EconBrief/appl/ProspectBoardList.asp";
# 				form.submit();
#
# 			}
# 			function page(page){
# 				var form = document.chForm;
#
# 				form.pageno.value = page;
# 				form.action = "/nCham/Service/EconBrief/appl/ProspectBoardList.asp";
# 				form.submit();
#
# 			}
# 			function go_search(){
# 				var form = document.chForm;
#
# 				form.action = "/nCham/Service/EconBrief/appl/ProspectBoardList.asp";
# 				form.submit();
# 			}
# 			function go_calendar(){
# 	//			var form = document.chForm;
# 	//			form.action = "";
# 	//			form.submit();
# 			}
#
#
# 			function LoadSimpleExample1() {
#
# 				win = window.open("/nCham/Service/popup/diary.asp?frm=chForm&obj=m_OldDate",null,"height=310,width=390,resizable=no,status=no,toolbar=no,menubar=no,location=no");
#
# 				//window.open("/nCham/Service/popup/diary.asp?frm=chForm&obj=m_OldDate",null,"height=310,width=390,resizable=no,status=no,toolbar=no,menubar=no,location=no");
#
# 				var winl = (screen.width - 390) / 2;
# 				var wint = (screen.height - 300) / 2;
# 				win.moveTo(winl,wint);
# 			}
#
# 			function LoadSimpleExample2() {
# 				win = window.open("/nCham/Service/popup/diary.asp?frm=chForm&obj=m_NowDate",null,"height=310,width=390,resizable=no,status=no,toolbar=no,menubar=no,location=no");
#
# 				//window.open("/nCham/service/popup/diary.asp?frm=chForm&obj=m_NowDate",null,"height=310,width=390,resizable=no,status=no,toolbar=no,menubar=no,location=no");
#
# 				var winl = (screen.width - 390) / 2;
# 				var wint = (screen.height - 300) / 2;
# 				win.moveTo(winl,wint);
# 			}
#
# 			function numkeyCheck(e) {
# 				var keyValue = event.keyCode;
# 				if( ((keyValue >= 48) && (keyValue <= 57)) ) return true;
# 				else return false;
# 				}
#
#
#
# 		</script>
# </head>
# <body>
# <!-- header area -->
# <header> <script src="/nCham/Service/js/common.js"></script> <div class="gnb"> <section> <nav class="tabsite"> <ul> <li> <a class="more" href="#"><span>패밀리</span></a> </li> <li> <a class="biz" href="https://sople.me" target="_new"><span>소플 so:ple</span></a> </li> <li> <a class="rent" href="/nCham/Service/Kcci/appl/RentState.asp"><span>회의실대관</span></a> </li> </ul> <div class="more-cont"> <!-- 접근성 쓰실때 링크에 대한 반전색이 있어야 합니다. --> <h3><span class="icon w-play"></span> 패밀리 사이트 더보기</h3> <ul> <li style="border-right:1px solid #4885b9;"> <ul> <li><a href="https://sople.me" target="_Blank">소플 so:ple<span class="icon r-triangle"></span></a></li> <li><a href="http://license.korcham.net/" target="_Blank">자격평가 <span class="icon r-triangle"></span></a></li> <li><a href="http://cert.korcham.net/" target="_Blank">원산지증명센터 <span class="icon r-triangle"></span></a></li> <li><a href="http://sandbox.korcham.net/" target="_Blank">샌드박스 지원센터 <span class="icon r-triangle"></span></a></li> <li><a href="https://thewave.net/" target="_Blank">WAVE<span class="icon r-triangle"></span></a></li> <li><a href="http://esg.korcham.net" target="_Blank">ESG 플랫폼 으쓱 <span class="icon r-triangle"></span></a></li> <li><a href="http://ert.korcham.net" target="_Blank">ERT-신기업가정신협의회 <span class="icon r-triangle"></span></a></li> <li><a href="http://sgi.korcham.net" target="_Blank">대한상의 SGI <span class="icon r-triangle"></span></a></li> <li><a href="http://wemeet.korcham.net" target="_Blank">위밋플랫폼 <span class="icon r-triangle"></span></a></li> </ul> </li> <li style="border-right:1px solid #4885b9;"> <ul> <li><a href="http://insure.korcham.net/" target="_Blank">공제센터<span class="icon r-triangle"></span></a></li> <li><a href="http://www.korcham-china.net/" target="_Blank">중국한국상회 <span class="icon r-triangle"></span></a></li> <li><a href="http://china.korcham.net/" target="_Blank">북경사무소 <span class="icon r-triangle"></span></a></li> <li><a href="http://vietnam.korcham.net/" target="_Blank">베트남사무소 <span class="icon r-triangle"></span></a></li> <li><a href="https://welfare.korcham.net" target="_Blank">중소기업복지플랫폼 <span class="icon r-triangle"></span></a></li> <li><a href="http://www.gs1kr.org/" target="_Blank">유통물류진흥원 <span class="icon r-triangle"></span></a></li> <li><a href="http://www.koreannet.or.kr/" target="_Blank">코리안넷 <span class="icon r-triangle"></span></a></li> <li><a href="http://www.oneshot.or.kr/" target="_Blank">사업재편종합지원센터 <span class="icon r-triangle"></span></a></li> <li><a href="http://www.korchamhrd.net/" target="_Blank">인력개발원 HRD포털 <span class="icon r-triangle"></span></a></li> </ul> </li> <li> <ul> <li><a href="http://www.teenup.or.kr/" target="_Blank">직업기초능력평가 <span class="icon r-triangle"></span></a></li> <li><a href="http://rc.korcham.net/" target="_Blank">서울지역 인적자원개발위원회 <span class="icon r-triangle"></span></a></li> </ul> </li> </ul> <a class="more-cont-close" href="#"><span class="icon close"></span></a> </div> </nav> <nav class="tmenu"> <ul> <li> <a href="/nCham/Service/Member/appl/login.asp">로그인</a> </li> <li> <a href="/nCham/Service/Member/appl/Join.asp">회원가입</a> </li> <li> <a href="http://english.korcham.net" target="blank">ENG</a> </li> <li> <a href="/nCham/Service/Member/appl/Sitemap.asp">사이트맵</a> </li> <li> <a href="/nCham/Service/Member/appl/FAQList.asp">고객센터</a> </li> </ul> </nav> </section> </div> <div class="menu"> <div class="menuwrap"> <section> <a href="javascript:goMain();"><img alt="대한상공회의소" src="/nCham/Service/imgs/img_top_logo.png"/></a> <nav> <ul> <li> <a href="/nCham/Service/Event/appl/KcciNewsList.asp">행사/교육</a> <ul class="subm"> <li><a href="/nCham/Service/Event/appl/KcciNewsList.asp">행사</a></li> <li><a href="/nCham/Service/Event/appl/EduNewsList.asp">교육</a></li> <li><a href="/nCham/Service/Event/appl/GuHubList.asp">서울 상공회</a></li> <li><a href="/nCham/Service/Consult/Onestop/Notice/appl/CenterIntro.asp">코참경영상담</a></li> <li><a href="/nCham/Service/Event/appl/AreaInfoList.asp">지역상의</a></li> </ul> </li> <li> <a href="/nCham/Service/Econom ...
# <!-- header area -->
# <div class="subTitTop">
# <h3 class="page-tit">일일경제지표</h3>
# </div>
# <nav class="cont-tab">
# <p class="snd_only">선택하시면 해당 카테고리로 정렬됩니다.</p>
# <!-- 해당 카테고리를 선택하면 a 테그 안에 <span class="icon d-arrow">정렬됨</span> 이 테그 안에 "정렬됨" 텍스트 를 넣어주세요. "정렬됨" 문구는 내부에서 정해서 바꿔주시면됩니다. curr 일때 넣어주시면 됩니다.-->
# <ul>
# <li><a class="curr" href="javascript:go_board_type(1)">금리 <span class="icon d-arrow">정렬됨</span></a></li>
# <li><a class="" href="javascript:go_board_type(2)">환율 <span class="icon d-arrow"></span></a></li>
# <li><a class="" href="javascript:go_board_type(3)">주가 <span class="icon d-arrow"></span></a></li>
# <!--li><a href="javascript:go_board_type(4)" class="">국제금리 <span class="icon d-arrow"></span></a></li-->
# <li><a class="" href="javascript:go_board_type(5)">국제주가 <span class="icon d-arrow"></span></a></li>
# <li><a class="" href="javascript:go_board_type(6)">국제유가 <span class="icon d-arrow"></span></a></li>
# </ul>
# </nav>
# <section class="searchbox">
# <form name="chForm" onsubmit="return go_search();">
# <input name="board_type" type="hidden" value="1"/>
# <input name="pageno" type="hidden" value=""/>
# <input name="daybt" type="radio" value="OneMonth"/> <span>최근한달간</span>
# 			<input name="daybt" type="radio" value="OneWeek"/> <span>최근일주일간</span>
# 			<input checked="" name="daybt" type="radio" value="OldNow"/> <span class="snd_only">검색기간 직접설정</span>
# <input id="bdr_as_sdate" name="m_OldDate" onkeypress="return numkeyCheck(event)" type="text" value="20140811"/>
# <a href="#" id="js_bdr_as_sdate"><img alt="검색시작일 선택" onclick="LoadSimpleExample1(); " src="/nCham/Service/img/sub/cal.png" style="vertical-align: middle;"/></a>
#
#
#
# 			~
# 			<input id="bdr_as_edate" name="m_NowDate" onkeypress="return numkeyCheck(event)" type="text" value="20240811"/>
# <a href="#" id="js_bdr_as_edate"><img alt="검색종료일 선택" onclick="LoadSimpleExample2(); " src="/nCham/Service/img/sub/cal.png" style="vertical-align: middle;"/></a>
# 			  <button class="icon b-search" onclick="javascript:go_search();" type="button">검색</button>
# </form>
# </section>
# <section class="board-list">
# <p class="bcnt">게시물 수 : <span>2,466</span>개</p>
# <div class="tablewrap">
# <table>
# <caption>보도자료</caption>
# <colgroup>
# <col width="16%"/><col width="16%"/><col width="16%"/><col width="16%"/><col width="16%"/><col width="*"/>
# </colgroup>
# <thead>
# <tr><th scope="col">날짜</th><th scope="col">콜금리</th><th scope="col">CD(91일)</th><th scope="col">국고채(3년)</th><th scope="col">국고채(5년)</th><th scope="col">회사채(3년,AA-)</th></tr>
# </thead>
# <tbody>
# <tr><td>2024.08.09</td><td>3.53</td><td>3.47</td><td>2.94</td><td>-</td><td>3.41</td></tr>
# <tr><td>2024.08.08</td><td>3.47</td><td>3.48</td><td>2.91</td><td>-</td><td>3.38</td></tr>
# <tr><td>2024.08.07</td><td>3.53</td><td>3.48</td><td>2.93</td><td>-</td><td>3.40</td></tr>
# <tr><td>2024.08.06</td><td>3.54</td><td>3.47</td><td>2.94</td><td>-</td><td>3.40</td></tr>
# <tr><td>2024.08.05</td><td>3.54</td><td>3.48</td><td>2.81</td><td>-</td><td>3.27</td></tr>
# <tr><td>2024.08.02</td><td>3.51</td><td>3.48</td><td>2.94</td><td>-</td><td>3.39</td></tr>
# <tr><td>2024.08.01</td><td>3.53</td><td>3.49</td><td>2.98</td><td>-</td><td>3.43</td></tr>
# <tr><td>2024.07.31</td><td>3.51</td><td>3.50</td><td>3.00</td><td>-</td><td>3.46</td></tr>
# <tr><td>2024.07.30</td><td>3.5</td><td>3.50</td><td>2.99</td><td>-</td><td>3.45</td></tr>
# <tr><td>2024.07.29</td><td>3.54</td><td>3.50</td><td>2.98</td><td>-</td><td>3.43</td></tr>
# <tr><td>2024.07.26</td><td>3.55</td><td>3.50</td><td>3.00</td><td>-</td><td>3.48</td></tr>
# <tr><td>2024.07.25</td><td>3.52</td><td>3.51</td><td>3.02</td><td>-</td><td>3.48</td></tr>
# <tr><td>2024.07.24</td><td>3.55</td><td>3.51</td><td>3.05</td><td>-</td><td>3.51</td></tr>
# <tr><td>2024.07.23</td><td>3.51</td><td>3.52</td><td>3.08</td><td>-</td><td>3.53</td></tr>
# <tr><td>2024.07.22</td><td>3.56</td><td>3.52</td><td>3.07</td><td>-</td><td>3.52</td></tr>
# </tbody>
# </table>
# </div>
# <div class="paging"><ul><li><a class="curr" href="#none">1</a></li><li><a href="javascript:page('2');">2</a></li><li><a href="javascript:page('3');">3</a></li><li><a href="javascript:page('4');">4</a></li><li><a href="javascript:page('5');">5</a></li><li><a href="javascript:page('6');">6</a></li><li><a href="javascript:page('7');">7</a></li><li><a href="javascript:page('8');">8</a></li><li><a href="javascript:page('9');">9</a></li><li><a href="javascript:page('10');">10</a></li><li class="next"><a href="javascript:page('11');" title="다음페이지">다음 <span class="icon paging-next"></span></a></li><li class="next"><a href="javascript:page('165');" title="마지막으로">마지막 <span class="icon paging-next"></span><span class="icon paging-next"></span></a></li></ul></div>
# <!--form action="" class="board-search">
# 			<select name="searchfield" id="searchfield">
# 				<option value="TITLE" >제목</option>
# 				<option value="COMPNM" >기업명</option>
# 				<option value="ALL" >전체검색</option>
# 			</select>
#
# 			<p class="search">
# 				<input type="text" name="searchworld" id="searchworld" value=""/>
# 				<button type="submit" class="icon b-search">검색</button>
# 			</p>
# 		</form-->
# </section>
# <!-- Left Menu Area -->
# <script type="text/javascript">
# 		$(document).ready(function() {
# 			$(".right_quick .slider ul").bxSlider({
# 				pager:true,controls:false,auto:true,default:5000,
# 				useCSS:false
# 			});
# 		});
# 	</script> <section class="right_quick" id="js_right_quick"> <img alt="" src="/nCham/Service/imgs/temp_right_quick2.png" usemap="#rightMap"/> <map name="rightMap"> <area coords="1,41,140,79" href="/nCham/Service/Network/appl/LocalcciList.asp" shape="rect"/> <area coords="1,81,140,119" href="/nCham/Service/Economy/appl/KcciReportList.asp" shape="rect"/> <area coords="1,123,140,160" href="https://sople.me" shape="rect" target="_new"/> <area coords="1,165,140,203" href="/nCham/Service/Event/appl/EduNewsList.asp" shape="rect"/> <area coords="1,205,140,243" href="/nCham/Service/Economy/appl/PhotoNewsList.asp" shape="rect"/> </map> <div class="slider"> <ul> <li> <a href="http://www.korcham.net/nCham/Service/Kcci/appl/RentState.asp"> <img alt="" src="/nCham/Service/imgs/quick_right_01.jpg"/> </a> </li> <li> <a href="https://sople.me" target="_new"> <img alt="" src="/nCham/Service/imgs/quick_right_04.png"/> </a> </li> <li> <a href="https://welfare.korcham.net" target="_new"> <img alt="" src="/nCham/Service/imgs/quick_right_05.jpg"/> </a> </li> <li> <a href="http://www.korcham.net/nCham/Service/Kcci/appl/KcciNoticeDetail.asp?nKey=197523"> <img alt="" src="/nCham/Service/imgs/quick_right_06.jpg"/> </a> </li> </ul> </div> <p class="top"> <a href="#top">top</a> </p> </section>
# <!-- Left Menu Area -->
# <!-- footer area -->
# </div> <footer> <section class="top"> <img alt="대한상공회의소" src="/nCham/Service/imgs/img_footer_logo.png" style="position:absolute;top:30px;left:0;"/> <div style="position:absolute;top:100px;left:0;"> <img src="/nCham/Service/imgs/kcci_sns_bottom.png" style="padding-left:10px;" usemap="#SNS_LINK"/> <map id="SNS_LINK" name="SNS_LINK"> <area coords="1,1,32,32" href="https://www.youtube.com/channel/UCtsmQ4ln18jB-rtyGQD6yXw" shape="rect" target="_new"/> <area coords="44,1,77,32" href="https://pf.kakao.com/_jqPsd" shape="rect" target="_new"/> <area coords="90,1,122,32" href="https://blog.naver.com/kccinews" shape="rect" target="_new"/> </map> </div> <nav class="sitemap"> <ul> <li> <a href="/nCham/Service/Event/appl/KcciNewsList.asp">행사/교육</a> <ul> <li><a href="/nCham/Service/Event/appl/KcciNewsList.asp">행사</a></li> <li><a href="/nCham/Service/Event/appl/EduNewsList.asp">교육</a></li> <li><a href="/nCham/Service/Event/appl/GuHubList.asp">서울 상공회</a></li> <li><a href="/nCham/Service/Consult/Onestop/Notice/appl/CenterIntro.asp">코참경영상담</a></li> <li><a href="/nCham/Service/Event/appl/AreaInfoList.asp">지역상의</a></li> </ul> </li> <li> <a href="/nCham/Service/Economy/appl/KcciReportList.asp">경제자료</a> <ul> <li><a href="/nCham/Service/Economy/appl/KcciReportList.asp">보도자료</a></li> <li><a href="/nCham/Service/Economy/appl/NewsBriefList.asp">브리프 &amp; 인포</a></li> <li><a href="/nCham/Service/Economy/appl/PhotoNewsList.asp">포토뉴스</a></li> <li><a href="/nCham/Service/Economy/appl/OnlineSeminarList.asp">온라인세미나</a></li> <li><a href="/nCham/Service/Economy/appl/EsgList.asp">ESG경영</a></li> <li><a href="/nCham/Service/Economy/appl/EconColumnList.asp">경제칼럼</a></li> <li><a href="/nCham/Service/Economy/appl/AreaReportList.asp">지역상의 보도자료</a></li> </ul> </li> <li> <a href="/nCham/Service/EconBrief/appl/EconInfoList.asp">산업소식</a> <ul> <li><a href="/nCham/Service/EconBrief/appl/EconInfoList.asp">경제정책정보</a></li> <li><a href="/nCham/Service/EconBrief/appl/ProspectList.asp">일일경제지표</a></li> <li><a href="/nCham/Service/EconBrief/appl/ComNewsList.asp">기업뉴스</a></li> <li><a href="/nCham/Service/EconBrief/appl/ExternalList.asp">유관기관소식</a></li> <li><a href="/nCham/Service/EconBrief/appl/Econtent.asp">e-Contents</a></li> <li><a href="/nCham/Service/ComicCeo/appl/ComicCeoList.asp">만화CEO열전</a></li> <li><a href="/nCham/Service/Economy/appl/PublishDataList.asp">발간자료</a></li> </ul> </li> <li> <a href="/nCham/Service/Network/appl/LocalcciList.asp">상의 네트워크</a> <ul> <li><a href="/nCham/Service/Network/appl/LocalcciList.asp">지역 상공회의소</a></li> <li><a href="/nCham/Service/Network/appl/guccilist.asp">서울 상공회</a></li> <li><a href="/nCham/Service/Kcci/appl/commbodTaxList.asp">위원회</a></li> <li><a href="/nCham/Service/Network/appl/KoreaForecci.asp">주한외국상공회의소</a></li> <li><a href="/nCham/Service/Network/appl/ForeigncciList.asp">외국상공회의소</a></li> <li><a href="/nCham/Service/Network/appl/HrdList.asp">인력개발원</a></li> <li><a href="/nCham/Service/Network/appl/LocalHireList.asp">지역상의 채용공고</a></li> </ul> </li> <li> <a href="/nCham/Service/Kcci/appl/CEOGreeting.asp">대한상공회의소 소개</a> <ul> <li><a href="/nCham/Service/Kcci/appl/CEOGreeting.asp">기관 소개</a></li> <li><a href="/nCham/Service/Kcci/appl/orgchart.asp">조직</a></li> <li><a href="/nCham/Service/Kcci/appl/MemberGuide.asp">회원제도</a></li> <li><a href="/nCham/Service/Kcci/appl/Serviceguide.asp">회원특화 제휴서비스</a></li> <li><a href="/nCham/Service/Kcci/appl/KcciNoticeList.asp">공지사항</a></li> <li><a href="/nCham/Service/Kcci/appl/Ethics.asp">윤리강령</a></li> <li><a href="/nCham/Service/Kcci/appl/RentState.asp">회의실대관</a></li> <li><a href="/nCham/Service/Kcci/appl/KcciLocation.asp">찾아오시는길</a></li> </ul> </li> </ul> </nav> </section> <section class="bottom"> <div> <nav> <ul> <li><a href="/nCham/Service/Private/appl/PersonalInfo.asp"><span class="stxt foot02">개인정보처리방침</span></a></li> <li><a href="/nCham/Service/Private/appl/VideoInfo.asp"><span class="stxt foot05">영상정보처리기기운영관리방침</span></a></li> </ul> </nav> <p>
# 				(우)04513 서울특별시 중구 세종대로 39 상공회의소회관   TEL: 02-6050-3114   Email: <a href="mailto:webmaster@korcham.net">webmaster@korcham.net</a> </p> <br/> <p>
# 				Copyrightⓒ KCCI. All Rights Reserved.
# 			</p> </div> </section> </footer> <script type="text/javascript">
# $(window).load(function() {
# 	mainAnimation();
# });
# </script> <script src="//wcs.naver.net/wcslog.js" type="text/javascript"></script> <script type="text/javascript">
#  if(!wcs_add) var wcs_add = {};
#  wcs_add["wa"] = "1e7a59430dc530";
#  if(window.wcs) {
#    wcs_do();
#  }
#  </script>
# <!-- footer area -->
# </body>
# </html>

# %%
table_tag = call_soup.select_one('div.tablewrap')

# %%
column_names = []
columns = table_tag.select('thead th')
for column in columns:
    column_names.append(column.text)
column_names
# Out:
# ['날짜', '콜금리', 'CD(91일)', '국고채(3년)', '국고채(5년)', '회사채(3년,AA-)']

# %%
rows = []
datas = table_tag.select('tbody tr')
for data in datas:
    row = [da.text for da in data.select('td')]
    rows.append(row)
rows
# Out:
# [['2024.08.09', '3.53', '3.47', '2.94', '-', '3.41'],
#  ['2024.08.08', '3.47', '3.48', '2.91', '-', '3.38'],
#  ['2024.08.07', '3.53', '3.48', '2.93', '-', '3.40'],
#  ['2024.08.06', '3.54', '3.47', '2.94', '-', '3.40'],
#  ['2024.08.05', '3.54', '3.48', '2.81', '-', '3.27'],
#  ['2024.08.02', '3.51', '3.48', '2.94', '-', '3.39'],
#  ['2024.08.01', '3.53', '3.49', '2.98', '-', '3.43'],
#  ['2024.07.31', '3.51', '3.50', '3.00', '-', '3.46'],
#  ['2024.07.30', '3.5', '3.50', '2.99', '-', '3.45'],
#  ['2024.07.29', '3.54', '3.50', '2.98', '-', '3.43'],
#  ['2024.07.26', '3.55', '3.50', '3.00', '-', '3.48'],
#  ['2024.07.25', '3.52', '3.51', '3.02', '-', '3.48'],
#  ['2024.07.24', '3.55', '3.51', '3.05', '-', '3.51'],
#  ['2024.07.23', '3.51', '3.52', '3.08', '-', '3.53'],
#  ['2024.07.22', '3.56', '3.52', '3.07', '-', '3.52']]

# %%
interest_url = 'https://www.bok.or.kr/portal/singl/baseRate/list.do'
interest_params = {
    'dataSeCd': '01',
    'menuNo': '200643'
}
interest_res = requests.get(interest_url, params=interest_params)
interest_res.status_code
# Out:
# 200

# %%
int_soup = bs(interest_res.text)
int_soup
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title> | 한국은행 기준금리 추이(목록) | 통화정책방향 | 통화정책 | 정책/업무 |  한국은행 홈페이지</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="한국은행 기준금리 추이" property="title"/>
# <meta content="한국은행" property="main"/>
# <meta content="" property="creator"/>
# <meta content="한국은행" property="publisher"/>
# <meta content=" | 한국은행 기준금리 추이(목록) | 통화정책방향 | 통화정책 | 정책/업무 |  한국은행 홈페이지" property="subject"/>
# <meta content="" property="keyword"/>
# <meta content="" property="description"/>
# <link href="https://static-cdn.bok.or.kr/static/commons/bok.ico" rel="icon" type="image/x-icon"/>
# <link href="https://static-cdn.bok.or.kr/static/portal/css/sub.css" rel="stylesheet"/>
# <script src="https://static-cdn.bok.or.kr/static/jslibrary/jquery-3.5.1.min.js"></script>
# <script src="https://static-cdn.bok.or.kr/static/jslibrary/bootstrap/bootstrap.min.js"></script>
# <script src="https://static-cdn.bok.or.kr/static/jslibrary/bootstrap-datepicker-1.9.0-dist/js/bootstrap-datepicker.min.js"></script>
# <script src="https://static-cdn.bok.or.kr/static/jslibrary/typeahead.bundle.js"></script>
# <link href="https://static-cdn.bok.or.kr/static/jslibrary/swiper@8/swiper-bundle.min.css" rel="stylesheet"/>
# </head>
# <body>
# <ul class="skip">
# <li><a href="#content">본문내용 바로가기</a></li>
# <li><a href="#gnb">주메뉴 바로가기</a></li>
# </ul>
# <!-- <div id="bgW"></div>
# <div id="bgW2"></div>
# <div class="bg_Allmenu"></div> -->
# <!-- <div class="wrapSet"> -->
# <div id="wrap">
# <script src="https://static-cdn.bok.or.kr/static/search/search.js"></script>
# <!-- header -->
# <header class="family" id="header">
# <div class="globalHeader">
# <div class="container">
# <ul>
# <!-- <li>
# 						<a href="/portal/main/main.do" target="_blank" title="새창열림">한국은행</a>
# 					</li> -->
# <li>
# <a href="/imer/main/main.do" target="_blank" title="새창열림">경제연구원</a>
# </li>
# <li>
# <a href="/museum/main/main.do" target="_blank" title="새창열림">화폐박물관</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqt.do?menuNo=200219">지역본부</a>
# </li>
# <li>
# <a href="https://ecos.bok.or.kr" target="_blank" title="새창열림">경제통계시스템(ECOS)</a>
# </li>
# <li>
# <a href="https://snapshot.bok.or.kr" target="_blank" title="새창열림">금융·경제 스냅샷</a>
# </li>
# <li>
# <a href="https://dl.bok.or.kr" target="_blank" title="새창열림">전자도서관</a>
# </li>
# <li>
# <a href="https://archives.bok.or.kr" target="_blank" title="새창열림">디지털아카이브</a>
# </li>
# <li>
# <a href="https://apply.bok.or.kr" target="_blank" title="새창열림">채용</a>
# </li>
# </ul>
# <div class="m-globalHeader">
# <div class="site_go">
# <button title="Family site 열기" type="button">관련사이트 바로가기</button>
# <ul>
# <li>
# <a href="/portal/main/main.do" target="_blank" title="새창열림">한국은행</a>
# </li>
# <li>
# <a href="/museum/main/main.do" target="_blank" title="새창열림">화폐박물관</a>
# </li>
# <li>
# <a href="/imer/main/main.do" target="_blank" title="새창열림">경제연구원</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqt.do?menuNo=200219">지역본부</a>
# </li>
# <li>
# <a href="https://ecos.bok.or.kr" target="_blank" title="새창열림">경제통계시스템(ECOS)</a>
# </li>
# <li>
# <a href="https://snapshot.bok.or.kr" target="_blank" title="새창열림">금융·경제 스냅샷</a>
# </li>
# <li>
# <a href="https://dl.bok.or.kr" target="_blank" title="새창열림">전자도서관</a>
# </li>
# <li>
# <a href="https://archives.bok.or.kr" target="_blank" title="새창열림">디지털아카이브</a>
# </li>
# <li>
# <a href="https://apply.bok.or.kr" target="_blank" title="새창열림">채용</a>
# </li>
# </ul>
# </div>
# </div>
# <!-- 본인인증 -->
# <div class="g-info">
# <div class="global">
# <ul>
# <li>
# <a href="/portal/mber/bokMber/forSelfCrtfc.do?menuNo=200249">본인인증</a>
# </li>
# <li>
# <a href="/eng/main/main.do" target="_blank" title="새창열림">ENGLISH</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="container">
# <h1 class="logo">
# <a href="/portal/main/main.do">
# <span class="sr-only">한국은행 BANK OF KOREA</span>
# </a>
# </h1>
# <!-- gnb -->
# <nav class="gnb" id="gnb">
# <ul>
# <li class="menu01">
# <a href="/portal/submain/submain/bokIntrcn.do?menuNo=201650"><span>한국은행</span></a>
# <div class="depth2">
# <ul>
# <li>
# <a href="/portal/submain/submain/bokIntrcn.do?menuNo=201650">한국은행이 하는 일</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201688">설립목적 및 역사</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/main/contents.do?menuNo=200781">한국은행법의 변천</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200196">역대총재</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201696">금융통화위원회</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/main/contents.do?menuNo=201696">금융통화위원회</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201663">금융통화위원회의 역사</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200184">조직도</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200182">운영 및 법규</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/main/contents.do?menuNo=200182">전략 및 조직가치</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200509">경영정보</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200794">계약정보</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200969">윤리경영</a>
# </li>
# <li>
# <a href="/portal/singl/law/listSearch.do?menuNo=200200">법규정보</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200212">사회공헌</a>
# </li>
# <li>
# <a href="https://apply.bok.or.kr/" target="_blank" title="새창 열림">채용</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200505">오시는 길</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/main/contents.do?menuNo=200505">본부</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201628">지역본부</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200508">인재개발원</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqt.do?menuNo=200219">지역본부</a>
# <div class="depth3">
# <ul>
# <li class="on">
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z11&amp;menuNo=201672">부산본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z12&amp;menuNo=201673">대구경북본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z13&amp;menuNo=201674">목포본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z14&amp;menuNo=201675">광주전남본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z15&amp;menuNo=201676">전북본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z16&amp;menuNo=201677">대전세종충남본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z17&amp;menuNo=201678">충북본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z18&amp;menuNo=201679">강원본부</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a class="sr-only" href="/portal/submain/submain/rgHqt.do?menuNo=200219">지역본부</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z19&amp;menuNo=201680">인천본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z20&amp;menuNo=201681">제주본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z21&amp;menuNo=201682">경기본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z22&amp;menuNo=201683">경남본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z23&amp;menuNo=201684">강릉본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z24&amp;menuNo=201685">울산본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z25&amp;menuNo=201686">포항본부</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqtSub.do?searchBbsSeCd=z01&amp;menuNo=201687">강남본부</a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# <div class="e">
# <a href="/portal/main/contents.do?menuNo=201688">
# <span class="img" style="background-image: url(https://media-cdn.bok.or.kr/4ec51339419eb35404357c733a24ac4128ac1e3514ba1cb9998a414784c82286/0d1bf30daf5b022bd54647441af3874affc8915a9eb18c9a94bb7f933601059813e27cc0df58d0800d2b142a2917067e/thumbFile.);"></span>
# <span class="txt">한국은행</span>
# </a>
# </div>
# </div>
# </li>
# <!-- 추후 추가 -->
# <li class="menu02 active">
# <a href="/portal/submain/submain/crncyPolicy.do?menuNo=201651"><span>정책/업무</span></a>
# <div class="depth2">
# <ul>
# <li>
# <a href="/portal/submain/submain/crncyPolicy.do?menuNo=201651">통화정책</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/submain/submain/crncyPolicy.do?menuNo=201651">통화정책 소개</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200288">목표 및 운영체계</a>
# </li>
# <li>
# <a href="/portal/singl/crncyPolicyDrcMtg/listYear.do?mtgSe=A&amp;menuNo=200755">통화정책방향</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200294">통화정책수단</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/submain/submain/fnncSafety.do?menuNo=201652">금융안정</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/submain/submain/fnncSafety.do?menuNo=201652">금융안정업무 소개</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200316">금융시스템</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200321">금융안정의 이해</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201069">KOFR</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/submain/submain/paymtStlmnt.do?menuNo=201655">지급결제</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/submain/submain/paymtStlmnt.do?menuNo=201655">지급결제업무 소개</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200345">지급결제제도</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200770">지급결제제도와 한국은행</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200356">금융정보화</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200733">모바일현금카드·거스름돈 적립서비스</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/submain/submain/cbdc.do?menuNo=201136">CBDC</a>
# </li>
# <li>
# <a href="/portal/submain/submain/govBonds.do?menuNo=201656">국고증권</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/submain/submain/govBonds.do?menuNo=201656">국고증권업무 소개</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200361">국고업무</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200362">증권업무</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/submain/submain/frxcg.do?menuNo=201657">외환</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/submain/submain/frxcg.do?menuNo=201657">외환업무 소개</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200025">외환정책과 외환제도</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200406">외환시장과 환율</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200408">외환시장운영협의회</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200411">외환보유액</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200398">외환거래심사</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/submain/submain/interCoop.do?menuNo=201658">국제협력</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/submain/submain/interCoop.do?menuNo=201658">국제협력업무 소개</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201645">중앙은행 협력기구</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201644">국제금융기구 및 국제회의체</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201135">통화스왑 현황</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201667">KPP &amp; CBSP</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200417">관련 사이트</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/submain/submain/crrncy.do?menuNo=201654">화폐</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/submain/submain/crrncy.do?menuNo=201654">화폐업무 소개</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200017">현용화폐</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200766">기념화폐</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200388">화폐홍보교육</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200370">위조 및 훼손</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200391">화폐 관련 법규</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200393">화폐교환 및 주화수급</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/submain/submain/climateChange.do?menuNo=201653">기후변화대응</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/submain/submain/climateChange.do?menuNo=201653">기후변화대응 소개</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201257">기후변화와 한국은행</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/submain/submain/sts.do?menuNo=201659">경제통계</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/submain/submain/sts.do?menuNo=201659">경제통계업무 소개</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200998">경제통계 개요</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200095">주요통계 해설</a>
# </li>
# <li>
# <a href="/portal/stats/statsPublictSchdul/listCldr.do?menuNo=200775">통계공표일정</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?pageIndex=&amp;targetDepth=3&amp;menuNo=201252&amp;syncMenuChekKey=4&amp;searchCnd=1&amp;searchKwd=&amp;depth2=201157&amp;depth3=201252&amp;depth4=200097&amp;date=&amp;sdate=&amp;edate=&amp;sort=1&amp;pageUnit=10">통계조사표</a>
# </li>
# <li>
# <a href="https://ecos.bok.or.kr/#/Short/0000000001" target="_blank" title="새창 열림">통계검색</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/submain/submain/ecEdu.do?menuNo=201254">경제교육</a>
# </li>
# </ul>
# <div class="e">
# <a href="/portal/submain/submain/crncyPolicy.do?menuNo=201651">
# <span class="img" style="background-image: url(https://media-cdn.bok.or.kr/4ec51339419eb35404357c733a24ac4173e9f9c0f43ee1d364ede5ec6b25a07b/5220e5e1de59a862d3112c7ebb84cb7e325047806c09ad8286c8c5ea7c6e51b954ef47f17be083a72adbfab973dda727/thumbFile.);"></span>
# <span class="txt">정책/업무</span>
# </a>
# </div>
# </div>
# </li>
# <li class="menu03">
# <a href="/portal/singl/newsData/list.do?menuNo=201150"><span>뉴스/자료</span></a>
# <div class="depth2">
# <ul>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200038">뉴스 및 의사록</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201263">보도자료</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200039">주간보도계획</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200040">언론보도해명자료</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201154">금융통화위원회 의사록 및 의결사항</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200037">공지사항</a>
# </li>
# <li>
# <a href="/portal/singl/mainEvent/listCldr.do?menuNo=200035">주요행사</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201155">연설 및 강연</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200041">총재</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201266">금통위원</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201106">블로그</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200699">간행물</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200071">연차보고서</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200067">통화신용정책보고서</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200068">금융안정보고서</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200066">경제전망보고서</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200069">지역경제보고서</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200072">지급결제보고서</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200437">해외경제 포커스</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200439">경제상황 평가</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201103">국민계정리뷰</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200454">국민계정</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200455">기업경영분석</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200457">산업연관표</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200079">단행본</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200774">기타간행물</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201156">조사연구</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200433">BOK 이슈노트</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200440">경제분석</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200431">BOK 경제연구</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201140">경제전망 핵심이슈·심층연구</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200327">금융안정 조사연구</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200706">지급결제 조사연구</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200707">통계연구</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200092">북한경제자료</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201042">지역연구자료</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201127">주력산업 모니터링 보고서</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200560">조사연구자료</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200558">지역경제일지</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200559">지역경제통계</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200557">지역경제동향</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201090">공동연구자료</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200080">국외사무소자료</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200081">뉴욕사무소</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200082">워싱턴주재원</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200083">프랑크푸르트사무소</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200084">동경사무소</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200085">런던사무소</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200086">북경사무소</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200087">홍콩주재원</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200088">상해주재원</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201157">업무별 정보</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201272">경영정보</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201287">계약정보</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201204">통화정책</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201205">금융안정</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201271">금융시장</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201224">지급결제</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201234">국고증권</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201241">외환시장</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201293">외환심사</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201218">화폐</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201701">기후변화 대응</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201252">경제통계</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201269">경제교육</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201702">지역본부</a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# <div class="e">
# <a href="/portal/singl/newsData/list.do?menuNo=201150">
# <span class="img" style="background-image: url(https://media-cdn.bok.or.kr/4ec51339419eb35404357c733a24ac4173e9f9c0f43ee1d364ede5ec6b25a07b/fc47799ef0feda02bd404aa9f3d9d10ea4fae33e5ae894fd10c09bfa3648fa4313e27cc0df58d0800d2b142a2917067e/thumbFile.);"></span>
# <span class="txt">뉴스/자료</span>
# </a>
# </div>
# </div>
# </li>
# <li class="menu04">
# <a href="/portal/singl/multiCont/list.do?menuNo=201151"><span>멀티콘텐츠</span></a>
# <div class="depth2">
# <ul>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201213">동영상</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201295">총재기자간담회</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201297">보도자료설명회</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=200428">컨퍼런스·세미나</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=200058">영상보고서</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201691">기획동영상</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201217">홍보동영상</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201300">경제교육</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=200062">기타영상</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201214">카드뉴스</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201216">화폐홍보</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201303">경제교육</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201671">CBDC</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201215">소셜미디어</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201302">기타</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201304">웹툰</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201305">창립 70주년 기념 웹툰</a>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=201036">경제교육웹툰</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/singl/multiCont/list.do?menuNo=200042">한은소식</a>
# </li>
# </ul>
# <div class="e">
# <a href="/portal/singl/multiCont/list.do?menuNo=201213">
# <span class="img" style="background-image: url(https://media-cdn.bok.or.kr/4ec51339419eb35404357c733a24ac4173e9f9c0f43ee1d364ede5ec6b25a07b/ed934e30225752d7e65b02014d651d0c1bb6f1e1bda8cd717670fe8a7488fdb613e27cc0df58d0800d2b142a2917067e/thumbFile.);"></span>
# <span class="txt">멀티콘텐츠</span>
# </a>
# </div>
# </div>
# </li>
# <li class="menu05">
# <a href="/portal/submain/submain/primaryService.do?menuNo=201660"><span>대국민 서비스</span></a>
# <div class="depth2">
# <ul>
# <li>
# <a href="/portal/submain/submain/primaryService.do?menuNo=201660">개요</a>
# </li>
# <li>
# <a href="/portal/singl/mainEvent/listCldr.do?menuNo=200035">주요행사</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/singl/mainEvent/listCldr.do?menuNo=200035">행사일정</a>
# </li>
# <li>
# <a href="/portal/singl/mainEvent/list.do?menuNo=200036">컨퍼런스/세미나</a>
# </li>
# <li>
# <a href="/portal/pgm/master/list.do?progrmSeCd=01&amp;menuNo=200419">행사참가신청</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200172">뉴스레터</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/main/contents.do?menuNo=200172">뉴스레터 서비스 안내 및 신청</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200496">경제교육</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/main/contents.do?menuNo=200496">프로그램안내</a>
# </li>
# <li>
# <a href="/portal/ecEdu/friLectr/list.do?menuNo=200603">교육신청</a>
# </li>
# <li>
# <a href="/portal/ecEdu/friLectrReq/listCmpl.do?menuNo=200631">수료증발급</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201039">온라인학습</a>
# </li>
# <li>
# <a href="/portal/ecEdu/ecWordDicary/search.do?menuNo=200688">경제용어사전</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200393">화폐교환 및 주화수급</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/main/contents.do?menuNo=200393">화폐 교환 기준 및 방법</a>
# </li>
# <li>
# <a href="/portal/singl/coxhResve/listCldr.do?menuNo=201082">대량주화 교환신청</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200158">주화수급정보센터</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/museum/main/contents.do?menuNo=700112">화폐박물관</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/museum/main/contents.do?menuNo=700112" target="_blank" title="새창 열림">이용안내</a>
# </li>
# <li>
# <a href="/museum/singl/grupBkng/listCldr.do?menuNo=700791" target="_blank" title="새창 열림">예약하기</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200398">외환거래 심사</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/main/contents.do?menuNo=200398">외환거래심사업무 안내</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200404">외환거래별 신고</a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200402">외환거래 법규안내</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201320">금융제제대상자 지급 등 허가</a>
# </li>
# <li>
# <a href="https://fxra.bok.or.kr:4443" target="_blank" title="새창 열림">온라인 외환심사 시스템</a>
# </li>
# </ul>
# </div>
# </li>
# <li>
# <a href="/portal/bbs/P0001949/list.do?menuNo=200658">민원</a>
# <div class="depth3">
# <ul>
# <li>
# <a href="/portal/bbs/P0001949/list.do?menuNo=200658">민원FAQ</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200661">민원신청</a>
# </li>
# <li>
# <a href="https://voc.bok.or.kr/erms/myQna/listConfirmForm.action?menuNaviId=2259&amp;myQnaMngBean.crntPage=1" target="_blank" title="새창 열림">나의 민원 조회</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201119">CLEAN신고</a>
# </li>
# </ul>
# </div>
# </li>
# </ul>
# <div class="e">
# <a href="/portal/submain/submain/primaryService.do?menuNo=201660">
# <span class="img" style="background-image: url(https://media-cdn.bok.or.kr/4ec51339419eb35404357c733a24ac41ef0c2cef0f145be8f6d5a051678d4c05/c44aec2a99d40456d5ba336d84402039db4708329393556b7109d2129f324df013e27cc0df58d0800d2b142a2917067e/thumbFile.);"></span>
# <span class="txt">대국민 서비스</span>
# </a>
# </div>
# </div>
# </li>
# </ul>
# </nav>
# <div class="toggle-set">
# <!-- 본인인증, 영문페이지  이동-->
# <div class="m-g-info">
# <div class="global">
# <ul>
# <li>
# <a href="/portal/mber/bokMber/forSelfCrtfc.do?menuNo=200249">본인인증</a>
# </li>
# <li>
# <a href="/eng/main/main.do" target="_blank" title="새창열림">ENGLISH</a>
# </li>
# </ul>
# </div>
# </div>
# <button class="all-nav-toggle" data-backdrop="static" data-target="#totalMenu" data-toggle="modal" title="전체 메뉴 열기" type="button"></button>
# <button class="search" title="검색레이어 열기" type="button"></button>
# <div class="search_wrap">
# <form action="/portal/search/search/main.do" id="topSearchFrm" name="topSearchFrm">
# <input name="menuNo" type="hidden" value="201693"/>
# <div class="search_wrap_input">
# <input autocomplete="off" class="search_keyword" id="queryTop" maxlength="50" name="query" placeholder="검색어를 입력해 주세요." title="검색어" type="text"/>
# <button aria-label="검색" class="btn_search search" type="button"></button>
# </div>
# <button aria-label="검색 닫기" class="search_close" type="button"></button>
# </form>
# </div>
# </div>
# </div>
# <!-- 전체메뉴 -->
# <div class="modal fade total-nav" id="totalMenu" role="dialog" tabindex="-1">
# <div class="lpop modal-dialog" role="document">
# <div class="set modal-content">
# <div class="modal-header">
# <div class="container">
# <button class="close" data-dismiss="modal" type="button"><i class="ti-close"></i><span class="sr-only">레이어 창닫기</span></button>
# <h1 class="modal-title" id="modal-label1">
# <span class="totalnav-logo"></span>전체메뉴
# 							</h1>
# <form onsubmit="return false;">
# <fieldset>
# <legend class="sr-only">전체메뉴 검색</legend>
# <div class="keyword-set">
# <span class="keyword"><input id="searchWrdMenu" name="searchWrdMenu" title="검색어" type="text"/></span>
# <button aria-label="검색" class="search" onclick="searchMenu();" type="button"></button>
# </div>
# </fieldset>
# </form>
# </div>
# </div>
# <script>
# 						$(document).ready(function(){
# 							$("input[name='searchWrdMenu']").keydown(function (key){
# 								if(key.keyCode == 13){
# 									searchMenu();
# 								}
# 							});
# 						});
#
# 						function searchMenu(){
# 							$('span').removeClass('highlight');
# 							$('.dp2 > li').attr('class', 'dropdown');
# 							$('.dp3 > li').attr('class', 'dropdown');
# 							$('.dp4 > li').attr('class', 'dropdown');
# 							var searchWrd = $('#searchWrdMenu').val();
#
# 							if(searchWrd.trim() != ""){
# 								for(var i = 0; i <= 4; i++){
# 									$($('.dp' + i).children('li').children('a')).each(function(){
# 										if($(this).text().includes(searchWrd)){
# 											$(this).html(function(_, html){
# 												return html.replace(new RegExp('(' + searchWrd + ')', 'g'), '<span><span class="highlight">$1</span></span>');
# 											});
#
# 											$(this).parents('li').parents('li').attr('class', 'dropdown on');
# 										};
# 									});
# 								};
# 							}
# 						};
#
# 					</script>
# <div class="modal-body">
# <div class="container">
# <ul class="dp1">
# <li>
# <a href="/portal/submain/submain/bokIntrcn.do?menuNo=201650"><span>한국은행</span></a>
# <a class="m-dp1" href="javascript:void(0)"><span>한국은행</span></a>
# <ul class="dp2">
# <li>
# <a href="/portal/submain/submain/bokIntrcn.do?menuNo=201650">한국은행이 하는 일</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201688">설립목적 및 역사</a>
# <ul class="dp3">
# <li>
# <a href="/portal/main/contents.do?menuNo=201688">
# <span>설립목적 및 역사</span>
# </a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200781">
# <span>한국은행법의 변천</span>
# </a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200196">
# <span>역대총재</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201696">금융통화위원회</a>
# <ul class="dp3">
# <li>
# <a href="/portal/main/contents.do?menuNo=201696">
# <span>금융통화위원회</span>
# </a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201663">
# <span>금융통화위원회의 역사</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200184">조직도</a>
# <ul class="dp3">
# </ul>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200182">운영 및 법규</a>
# <ul class="dp3">
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>전략 및 조직가치</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200182"><span>전략</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201072"><span>조직가치</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200810"><span>운영리스크 관리</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200186"><span>CI 소개</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>경영정보</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200509"><span>인원현황</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200513"><span>인건비 현황</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200071"><span>주요 업무 추진 현황</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200516"><span>재무현황</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200758"><span>외부감사 결과 등</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>계약정보</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200794"><span>계약정보 안내</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200520"><span>발주계획</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200521"><span>경쟁입찰계약현황</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200522"><span>수의계약현황</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>윤리경영</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200969"><span>윤리경영실천규범</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200211"><span>윤리경영활동</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201119"><span>CLEAN신고</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>법규정보</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/singl/law/listSearch.do?menuNo=200200"><span>법령 검색</span></a>
# </li>
# <li>
# <a href="/portal/singl/law/listGanada.do?menuNo=200201"><span>가나다 검색</span></a>
# </li>
# <li>
# <a href="/portal/singl/law/listBbs.do?bbsSe=rule&amp;menuNo=200203"><span>규정예고</span></a>
# </li>
# <li>
# <a href="/portal/singl/law/listBbs.do?bbsSe=lawyer&amp;menuNo=200204"><span>고문변호사 현황</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>사회공헌</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200212"><span>사회공헌활동</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200213"><span>사회기부현황</span></a>
# </li>
# </ul>
# </li>
# <li>
# <a href="https://apply.bok.or.kr/">
# <span>채용</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200505">오시는 길</a>
# <ul class="dp3">
# <li>
# <a href="/portal/main/contents.do?menuNo=200505">
# <span>본부</span>
# </a>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>지역본부</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=201628"><span>부산본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201629"><span>대구경북본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201630"><span>목포본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201631"><span>광주전남본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201632"><span>전북본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201633"><span>대전세종충남본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201634"><span>충북본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201635"><span>강원본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201636"><span>인천본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201637"><span>제주본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201638"><span>경기본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201639"><span>경남본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201640"><span>강릉본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201641"><span>울산본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201642"><span>포항본부</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201643"><span>강남본부</span></a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200508">
# <span>인재개발원</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqt.do?menuNo=200219">지역본부</a>
# </li>
# </ul>
# </li>
# </ul>
# <ul class="dp1">
# <li>
# <a href="/portal/submain/submain/crncyPolicy.do?menuNo=201651"><span>정책/업무</span></a>
# <a class="m-dp1" href="javascript:void(0)"><span>정책/업무</span></a>
# <ul class="dp2">
# <li>
# <a href="/portal/submain/submain/crncyPolicy.do?menuNo=201651">통화정책</a>
# <ul class="dp3">
# <li>
# <a href="/portal/submain/submain/crncyPolicy.do?menuNo=201651">
# <span>통화정책 소개</span>
# </a>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>목표 및 운영체계</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200288"><span>통화정책 목표</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200291"><span>물가안정목표제</span></a>
# </li>
# <li>
# <a href="/portal/singl/baseRate/progress.do?dataSeCd=01&amp;menuNo=200656"><span>한국은행 기준금리</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200293"><span>통화정책의 실제운영</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200289"><span>통화정책 효과의 파급</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>통화정책방향</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/singl/crncyPolicyDrcMtg/listYear.do?mtgSe=A&amp;menuNo=200755"><span>통화정책방향 결정회의</span></a>
# </li>
# <li>
# <a href="/portal/singl/baseRate/list.do?dataSeCd=01&amp;menuNo=200643"><span>한국은행 기준금리 추이</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>통화정책수단</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=201707"><span>공개시장운영</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200296"><span>여·수신제도</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200297"><span>지급준비제도</span></a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/submain/submain/fnncSafety.do?menuNo=201652">금융안정</a>
# <ul class="dp3">
# <li>
# <a href="/portal/submain/submain/fnncSafety.do?menuNo=201652">
# <span>금융안정업무 소개</span>
# </a>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>금융시스템</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200316"><span>금융시스템의 정의</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200317"><span>금융시스템의 기능</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200318"><span>우리나라의 금융시스템</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200365"><span>금융시장동향</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>금융안정의 이해</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200321"><span>개요</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200328"><span>금융안정 정책수단</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200323"><span>정책당국간 역할분담</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200324"><span>중앙은행과 금융안정</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201209"><span>금융안정포럼</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200339"><span>FSB와 BCBS</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201105"><span>글로벌 금융규제 뉴스레터</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200326"><span>금융안정 관련 해외사이트</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>KOFR</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=201069"><span>개요</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201065"><span>주요논의결과</span></a>
# </li>
# <li>
# <a href="/portal/bbs/B0000311/list.do?menuNo=201067"><span>FAQ</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201068"><span>유관기관 홈페이지</span></a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/submain/submain/paymtStlmnt.do?menuNo=201655">지급결제</a>
# <ul class="dp3">
# <li>
# <a href="/portal/submain/submain/paymtStlmnt.do?menuNo=201655">
# <span>지급결제업무 소개</span>
# </a>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>지급결제제도</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200345"><span>지급결제제도 개요</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200346"><span>지급결제제도와 중앙은행</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200347"><span>우리나라의 지급결제제도</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200354"><span>BIS 지급결제 및 시장인프라 위원회</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200359"><span>국내외 지급결제 관련기관</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>지급결제제도와 한국은행</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200770"><span>한국은행의 역할 개요</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200349"><span>지급결제제도의 감시</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200350"><span>감시대상 지급결제시스템</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200720"><span>지급결제수단의 제공</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200727"><span>한은금융망 운영</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201665"><span>국제금융전문표준(ISO20022) 도입</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200352"><span>결제부족자금 지원</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200721"><span>결제완결성 보장대상 지급결제시스템 지정</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>금융정보화</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200356"><span>추진체계</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200357"><span>관계법령</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200728"><span>추진현황</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200358"><span>금융표준화</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200729"><span>제정/개정 표준</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200730"><span>관련자료</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>모바일현금카드·거스름돈 적립서비스</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200733"><span>모바일현금카드 개요</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200734"><span>모바일현금카드 이용방법</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200735"><span>거스름돈 적립서비스</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200736"><span>거스름돈 적립서비스 참여</span></a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/submain/submain/cbdc.do?menuNo=201136">CBDC</a>
# </li>
# <li>
# <a href="/portal/submain/submain/govBonds.do?menuNo=201656">국고증권</a>
# <ul class="dp3">
# <li>
# <a href="/portal/submain/submain/govBonds.do?menuNo=201656">
# <span>국고증권업무 소개</span>
# </a>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>국고업무</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200361"><span>한국은행의 국고업무</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200363"><span>국고업무자료</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>증권업무</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200362"><span>한국은행의 증권업무</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201236"><span>증권업무자료</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200364"><span>국채 발행 및 환매공고</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200698"><span>국채관련 물가연동계수</span></a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/submain/submain/frxcg.do?menuNo=201657">외환</a>
# <ul class="dp3">
# <li>
# <a href="/portal/submain/submain/frxcg.do?menuNo=201657">
# <span>외환업무 소개</span>
# </a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200025">
# <span>외환정책과 외환제도</span>
# </a>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>외환시장과 환율</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200406"><span>외환시장</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200407"><span>환율</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200031"><span>금리 및 환율 동향</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200994"><span>외환당국 순거래</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>외환시장운영협의회</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200408"><span>협의회 현황</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200409"><span>활동 상황</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200805"><span>협의회 규정</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200806"><span>서울외환시장 행동규범</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201249"><span>글로벌 외환시장행동규범</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200808"><span>글로벌 규범 이행선언서</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200410"><span>관련 사이트</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201250"><span>외환시장 구조 개선 Portal</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>외환보유액</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200411"><span>외환보유액의 의의</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200412"><span>운용목표</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200413"><span>운용현황</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200414"><span>리스크관리</span></a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200398">
# <span>외환거래심사</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/submain/submain/interCoop.do?menuNo=201658">국제협력</a>
# <ul class="dp3">
# <li>
# <a href="/portal/submain/submain/interCoop.do?menuNo=201658">
# <span>국제협력업무 소개</span>
# </a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201645">
# <span>중앙은행 협력기구</span>
# </a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201644">
# <span>국제금융기구 및 국제회의체</span>
# </a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201135">
# <span>통화스왑 현황</span>
# </a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201667">
# <span>KPP &amp; CBSP</span>
# </a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200417">
# <span>관련 사이트</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/submain/submain/crrncy.do?menuNo=201654">화폐</a>
# <ul class="dp3">
# <li>
# <a href="/portal/submain/submain/crrncy.do?menuNo=201654">
# <span>화폐업무 소개</span>
# </a>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>현용화폐</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200017"><span>현용은행권</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200367"><span>현용주화</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200377"><span>현용 화폐의 변천</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200380"><span>화폐연대자료</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>기념화폐</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200766"><span>기념은행권</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200368"><span>기념주화</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>화폐홍보교육</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=201078"><span>현금사용 선택권</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200388"><span>돈 깨끗이 쓰기</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200499"><span>화폐사랑 콘텐츠 공모전</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=201216"><span>화폐홍보 리플릿/포스터</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200742"><span>화페홍보 동영상</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200387"><span>화폐이야기</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>위조 및 훼손</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200370"><span>위조방지장치</span></a>
# </li>
# <li>
# <a href="/portal/singl/frgryMoneyNoSearch/search.do?menuNo=200378"><span>위조지폐 기번호 검색</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200396"><span>위조지폐 식별요령</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200745"><span>위조지폐 발견시 처리요령</span></a>
# </li>
# <li>
# <a href="/portal/singl/newsData/list.do?menuNo=200746"><span>위조지폐 신고서식</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200991"><span>주화 훼손 및 훼손 주화 발견시 처리요령</span></a>
# </li>
# </ul>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>화폐 관련 법규</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=200391"><span>화폐관련 법령</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200392"><span>화폐도안 이용기준</span></a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200393">
# <span>화폐교환 및 주화수급</span>
# </a>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/submain/submain/climateChange.do?menuNo=201653">기후변화대응</a>
# <ul class="dp3">
# <li>
# <a href="/portal/submain/submain/climateChange.do?menuNo=201653">
# <span>기후변화대응 소개</span>
# </a>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>기후변화와 한국은행</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/main/contents.do?menuNo=201257"><span>중앙은행과 기후변화</span></a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=201258"><span>대응전략</span></a>
# </li>
# </ul>
# </li>
# </ul>
# </li>
# <li>
# <a href="/portal/submain/submain/sts.do?menuNo=201659">경제통계</a>
# <ul class="dp3">
# <li>
# <a href="/portal/submain/submain/sts.do?menuNo=201659">
# <span>경제통계업무 소개</span>
# </a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200998">
# <span>경제통계 개요</span>
# </a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200095">
# <span>주요통계 해설</span>
# </a>
# </li>
# <li class="dropdown">
# <a href="javascript:void(0)" title="하위메뉴 열기">
# <span>통계공표일정</span>
# <i class="ico-arrow"></i>
# </a>
# <ul class="dp4">
# <li>
# <a href="/portal/stats/statsPublictSchdul/listCldr.do?menuNo=200775"><span>월간통계 공표일정</span></a>
# </li>
# <li>
# <a href="/portal/stats/statsPublictSchdul/listKnd.do?menuNo=200776"><span>통계종류별 공표일정</span></a>
# </li>
# <li>
# <a href="/portal/stats/sddsTrgetStats/listStats.do?menuNo=200777"><span>SDDS 대상통계 공표일정</span></a>
# </li>
# </ul>
# </li>
# <li>
# ...
#
# 				if(jqPlot.data[seriesIndex][pointIndex][0] === jqPlot.data[seriesIndex][jqPlot.data[seriesIndex].length-1][0] ){
#
# 					return "<strong>"+jqPlot.data[seriesIndex][pointIndex][0]+"시</strong><br><p class='h3'>"+  jqPlot.data[seriesIndex][pointIndex][1].toFixed(2) + "%</p>";
# 				}else{
# 					return "<strong>"+jqPlot.data[seriesIndex][pointIndex][0]+"</strong><br><p class='h3'>"+  jqPlot.data[seriesIndex][pointIndex][1].toFixed(2) + "%</p>";
# 				}
# 				//return "<strong>"+jqPlot.data[seriesIndex][pointIndex][0]+"</strong><br><p class='h3'>"+  jqPlot.data[seriesIndex][pointIndex][1].toFixed(2) + "%</p>";
# 			}
# 			/*formatString: '$%s\<br>\
# 			전년동기대비성장률 : %s \%'*/
# 		}
# 	});
# 	$('div.imgSet').resizable({delay: 20});
# 	$('div.imgSet').bind('resize', function(event, ui) {
# 		$("#chartObj2").width($('div.imgSet').width()*0.96)
# 		plot1.replot({resetAxes: true});
# 	});
# 	$(window).resize(function(){
# 		if($(window).width() >= 768){
# 			plot1.replot({
# 				resetAxes: {yaxis : true, y2axis : true},
# 				seriesDefaults : {
# 					pointLabels: {
# 						location: 'w'
# 					 }
# 				}
# 			});
# 		}else{
# 			plot1.replot({
# 				resetAxes: {yaxis : true, y2axis : true},
# 				seriesDefaults : {
# 					pointLabels: {
# 						location: 'n'
# 					 }
# 				}
# 			});
#
# 		}
# 	})
# });
# </script>
# <style>
# 	.jqplot-yaxis{
# 		margin-left: 5% !important;
# 		width: 5% !important;
# 	}
# 	.jqplot-y2axis{
# 		margin-left: 5% !important;
# 		width: 5% !important;
# 	}
# 	.jqplot-yaxis-label,
# 	.jqplot-y2axis-label{top:-20px !important; width: 50px !important;}
# 	.jqplot-xaxis-label{left:10% !important; }
# 	.jqplot-canvasOverlay-tooltip, .jqplot-cursor-tooltip, .jqplot-highlighter-tooltip{background-color: #fff;  z-index: 10; border:1px solid #c7c7c7; border-radius: 250px; padding: 30px 15px 15px 15px;height: 110px;  }
# 	.jqplot-point-label{z-index: 0; }
# 	@media (max-width: 767px){
# 		.jqplot-yaxis{
# 			margin-left: 3% !important;
# 			width: 3% !important;
# 		}
# 		.jqplot-y2axis{
# 			margin-left: 3% !important;
# 			width: 3% !important;
# 		}
# 	}
# </style>
# <div class="table tac">
# <table class="fixed">
# <caption>한국은행 기준금리 추이</caption>
# <thead>
# <tr>
# <th colspan="2" scope="col">변경일자</th>
# <th class="fb" scope="col">기준금리</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class="fb">2023</td>
# <td>01월 13일</td>
# <td>3.50</td>
# </tr>
# <tr>
# <td class="fb">2022</td>
# <td>11월 24일</td>
# <td>3.25</td>
# </tr>
# <tr>
# <td class="fb">2022</td>
# <td>10월 12일</td>
# <td>3.00</td>
# </tr>
# <tr>
# <td class="fb">2022</td>
# <td>08월 25일</td>
# <td>2.50</td>
# </tr>
# <tr>
# <td class="fb">2022</td>
# <td>07월 13일</td>
# <td>2.25</td>
# </tr>
# <tr>
# <td class="fb">2022</td>
# <td>05월 26일</td>
# <td>1.75</td>
# </tr>
# <tr>
# <td class="fb">2022</td>
# <td>04월 14일</td>
# <td>1.50</td>
# </tr>
# <tr>
# <td class="fb">2022</td>
# <td>01월 14일</td>
# <td>1.25</td>
# </tr>
# <tr>
# <td class="fb">2021</td>
# <td>11월 25일</td>
# <td>1.00</td>
# </tr>
# <tr>
# <td class="fb">2021</td>
# <td>08월 26일</td>
# <td>0.75</td>
# </tr>
# <tr>
# <td class="fb">2020</td>
# <td>05월 28일</td>
# <td>0.50</td>
# </tr>
# <tr>
# <td class="fb">2020</td>
# <td>03월 17일</td>
# <td>0.75</td>
# </tr>
# <tr>
# <td class="fb">2019</td>
# <td>10월 16일</td>
# <td>1.25</td>
# </tr>
# <tr>
# <td class="fb">2019</td>
# <td>07월 18일</td>
# <td>1.50</td>
# </tr>
# <tr>
# <td class="fb">2018</td>
# <td>11월 30일</td>
# <td>1.75</td>
# </tr>
# <tr>
# <td class="fb">2017</td>
# <td>11월 30일</td>
# <td>1.50</td>
# </tr>
# <tr>
# <td class="fb">2016</td>
# <td>06월 09일</td>
# <td>1.25</td>
# </tr>
# <tr>
# <td class="fb">2015</td>
# <td>06월 11일</td>
# <td>1.50</td>
# </tr>
# <tr>
# <td class="fb">2015</td>
# <td>03월 12일</td>
# <td>1.75</td>
# </tr>
# <tr>
# <td class="fb">2014</td>
# <td>10월 15일</td>
# <td>2.00</td>
# </tr>
# <tr>
# <td class="fb">2014</td>
# <td>08월 14일</td>
# <td>2.25</td>
# </tr>
# <tr>
# <td class="fb">2013</td>
# <td>05월 09일</td>
# <td>2.50</td>
# </tr>
# <tr>
# <td class="fb">2012</td>
# <td>10월 11일</td>
# <td>2.75</td>
# </tr>
# <tr>
# <td class="fb">2012</td>
# <td>07월 12일</td>
# <td>3.00</td>
# </tr>
# <tr>
# <td class="fb">2011</td>
# <td>06월 10일</td>
# <td>3.25</td>
# </tr>
# <tr>
# <td class="fb">2011</td>
# <td>03월 10일</td>
# <td>3.00</td>
# </tr>
# <tr>
# <td class="fb">2011</td>
# <td>01월 13일</td>
# <td>2.75</td>
# </tr>
# <tr>
# <td class="fb">2010</td>
# <td>11월 16일</td>
# <td>2.50</td>
# </tr>
# <tr>
# <td class="fb">2010</td>
# <td>07월 09일</td>
# <td>2.25</td>
# </tr>
# <tr>
# <td class="fb">2009</td>
# <td>02월 12일</td>
# <td>2.00</td>
# </tr>
# <tr>
# <td class="fb">2009</td>
# <td>01월 09일</td>
# <td>2.50</td>
# </tr>
# <tr>
# <td class="fb">2008</td>
# <td>12월 11일</td>
# <td>3.00</td>
# </tr>
# <tr>
# <td class="fb">2008</td>
# <td>11월 07일</td>
# <td>4.00</td>
# </tr>
# <tr>
# <td class="fb">2008</td>
# <td>10월 27일</td>
# <td>4.25</td>
# </tr>
# <tr>
# <td class="fb">2008</td>
# <td>10월 09일</td>
# <td>5.00</td>
# </tr>
# <tr>
# <td class="fb">2008</td>
# <td>08월 07일</td>
# <td>5.25</td>
# </tr>
# <tr>
# <td class="fb">2007</td>
# <td>08월 09일</td>
# <td>5.00</td>
# </tr>
# <tr>
# <td class="fb">2007</td>
# <td>07월 12일</td>
# <td>4.75</td>
# </tr>
# <tr>
# <td class="fb">2006</td>
# <td>08월 10일</td>
# <td>4.50</td>
# </tr>
# <tr>
# <td class="fb">2006</td>
# <td>06월 08일</td>
# <td>4.25</td>
# </tr>
# <tr>
# <td class="fb">2006</td>
# <td>02월 09일</td>
# <td>4.00</td>
# </tr>
# <tr>
# <td class="fb">2005</td>
# <td>12월 08일</td>
# <td>3.75</td>
# </tr>
# <tr>
# <td class="fb">2005</td>
# <td>10월 11일</td>
# <td>3.50</td>
# </tr>
# <tr>
# <td class="fb">2004</td>
# <td>11월 11일</td>
# <td>3.25</td>
# </tr>
# <tr>
# <td class="fb">2004</td>
# <td>08월 12일</td>
# <td>3.50</td>
# </tr>
# <tr>
# <td class="fb">2003</td>
# <td>07월 10일</td>
# <td>3.75</td>
# </tr>
# <tr>
# <td class="fb">2003</td>
# <td>05월 13일</td>
# <td>4.00</td>
# </tr>
# <tr>
# <td class="fb">2002</td>
# <td>05월 07일</td>
# <td>4.25</td>
# </tr>
# <tr>
# <td class="fb">2001</td>
# <td>09월 19일</td>
# <td>4.00</td>
# </tr>
# <tr>
# <td class="fb">2001</td>
# <td>08월 09일</td>
# <td>4.50</td>
# </tr>
# <tr>
# <td class="fb">2001</td>
# <td>07월 05일</td>
# <td>4.75</td>
# </tr>
# <tr>
# <td class="fb">2001</td>
# <td>02월 08일</td>
# <td>5.00</td>
# </tr>
# <tr>
# <td class="fb">2000</td>
# <td>10월 05일</td>
# <td>5.25</td>
# </tr>
# <tr>
# <td class="fb">2000</td>
# <td>02월 10일</td>
# <td>5.00</td>
# </tr>
# <tr>
# <td class="fb">1999</td>
# <td>05월 06일</td>
# <td>4.75</td>
# </tr>
# </tbody>
# </table>
# </div>
# <!-- <span class="fc_red">*</span> -->
# </h2><p class="fnote"> 2008년 2월 까지는 콜금리 목표, 2008년 3월부터는 한국은행 기준금리</p>
# </div>
# <!-- 만족도 조사, 자료관리 담당자 -->
# <div class="admin-set">
# <div class="satisfact">
# <p class="title">유용한 정보가 되었나요?</p>
# <form action="" id="stsfdgForm" method="post" name="stsfdgForm">
# <input name="menuNo" type="hidden" value="200643"/>
# <div class="radio-group">
# <label for="sati1">
# <input id="sati1" name="stsfdgIdex" type="radio" value="5"/>
# <i></i>
# <span>매우만족</span>
# </label>
# <label for="sati2">
# <input id="sati2" name="stsfdgIdex" type="radio" value="4"/>
# <i></i>
# <span>만족</span>
# </label>
# <label for="sati3">
# <input id="sati3" name="stsfdgIdex" type="radio" value="3"/>
# <i></i>
# <span>보통</span>
# </label>
# <label for="sati4">
# <input id="sati4" name="stsfdgIdex" type="radio" value="2"/>
# <i></i>
# <span>불만족</span>
# </label>
# <label for="sati5">
# <input id="sati5" name="stsfdgIdex" type="radio" value="1"/>
# <i></i>
# <span>매우불만족</span>
# </label>
# </div>
# <button type="submit">확인</button>
# </form>
# <script type="text/javascript">
# 								$("#stsfdgForm").submit(function() {
# 									if ($(this).find("input[name=stsfdgIdex]:checked").length == 0) {
# 										$(this).find("input[name=stsfdgIdex]").eq(0).focus();
# 										alert("페이지만족도를 선택해 주세요.");
# 										return false;
# 									}
#
# 									var url = "/portal/singl/stsfdg/insert.json";
# 									var params = $(this).serialize();
# 									$.post(url,params,function(data) {
# 										if (data.resultCode == "success") {
# 											alert("페이지만족도 의견이 등록되었습니다.");
# 											$("#stsfdgForm")[0].reset();
# 										}
# 										else if (data.resultCode == "duplicate") {
# 											alert("이미 등록하셨습니다.");
# 										}
# 										else {
# 											alert("페이지만족도 의견등록 오류입니다.");
# 										}
# 									},"json");
#
# 									return false;
# 								});
# 							</script>
# </div>
# <div class="info">
# <dl>
# <dt>담당부서</dt>
# <dd>
#
#
#
# 											통화정책국 정책총괄팀
#
#
# 									</dd>
# <dt class="sr-only">전화번호</dt>
# <dd>02-759-4442</dd>
# </dl>
# </div>
# </div>
# <!-- 만족도 조사, 자료관리 담당자 -->
# <!-- 내가 본 콘텐츠	-->
# <div class="my_memo">
# <button class="btn" title="내가 본 콘텐츠 열기" type="button">
# <span class="sr-only">내가 본 콘텐츠</span>
# </button>
# <div class="swiper">
# <div class="top">
# <h2>내가 본 콘텐츠</h2>
# <button class="close" title="내가 본 콘텐츠 닫기" type="button"></button>
# </div>
# <div class="swiper_body">
# <div class="swiper-wrapper" id="myView">
# </div>
# </div>
# <div class="ctrl">
# <button class="prev memo-prev" type="button">
# <i class="ctrl-prev"></i>
# <span class="sr-only">이전 내가 본 콘텐츠 보기</span>
# </button>
# <div class="swiper-pagination"></div>
# <button class="next memo-next" type="button">
# <i class="ctrl-next"></i>
# <span class="sr-only">다음 내가 본 콘텐츠 보기</span>
# </button>
# </div>
# <button class="b-close close" title="내가 본 콘텐츠 닫기" type="button"></button>
# </div>
# </div>
# <!-- //내가 본 콘텐츠	-->
# <!-- 맨 위로 -->
# <div class="goTop">
# <a href="javascript:void(0);">
# <span class="sr-only">페이지 위로 이동</span>
# </a>
# </div>
# </main>
# </div>
# <!-- Site footer -->
# <!-- footer -->
# <footer id="footer">
# <div class="container">
# <div class="f_l">
# <nav class="footer-nav">
# <ul>
# <li>
# <a href="/portal/main/contents.do?menuNo=200228">저작권보호방침</a>
# </li>
# <li class="point">
# <a href="/portal/main/contents.do?menuNo=200235">개인정보처리방침</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200230">이메일주소 무단 수집거부</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200238">홈페이지 이용안내</a>
# </li>
# <li>
# <a href="/portal/main/contents.do?menuNo=200575">관련사이트</a>
# </li>
# </ul>
# </nav>
# <div class="footer-bottom">
# <address>04531 서울특별시 중구 남대문로 39 (남대문로3가)<br class="mobile"/>
# 				대표전화 : 02-759-4114</address>
# <p class="copyright">Copyright(c) Bank of Korea. All rights reserved.</p>
# </div>
# </div>
# <div class="f_r">
# <div class="site_go">
# <button title="Family site 열기" type="button">Family site</button>
# <ul>
# <li>
# <a href="/portal/main/main.do" target="_blank" title="새창열림">한국은행</a>
# </li>
# <li>
# <a href="/imer/main/main.do" target="_blank" title="새창열림">경제연구원</a>
# </li>
# <li>
# <a href="/museum/main/main.do" target="_blank" title="새창열림">화폐박물관</a>
# </li>
# <li>
# <a href="/portal/submain/submain/rgHqt.do?menuNo=200219">지역본부</a>
# </li>
# <li>
# <a href="https://ecos.bok.or.kr" target="_blank" title="새창열림">경제통계시스템(ECOS)</a>
# </li>
# <li>
# <a href="https://snapshot.bok.or.kr" target="_blank" title="새창열림">금융·경제 스냅샷</a>
# </li>
# <li>
# <a href="https://dl.bok.or.kr" target="_blank" title="새창열림">전자도서관</a>
# </li>
# <li>
# <a href="https://archives.bok.or.kr" target="_blank" title="새창열림">디지털아카이브</a>
# </li>
# <li>
# <a href="https://apply.bok.or.kr" target="_blank" title="새창열림">채용</a>
# </li>
# </ul>
# </div>
# <div class="f_sns">
# <a class="sns-youtube" href="https://www.youtube.com/thebankofkoreakr" target="_blank" title="새창열림">
# <i class="ico-youtube"></i>
# <span class="sr-only">한국은행 Youtube 바로가기 (https://www.youtube.com/thebankofkoreakr)</span>
# </a>
# <a class="sns-facebook" href="https://www.facebook.com/bankofkoreahub" target="_blank" title="새창열림">
# <i class="ico-facebook"></i>
# <span class="sr-only">한국은행 Facebook 바로가기 (https://www.facebook.com/bankofkoreahub)</span>
# </a>
# <a class="sns-instagram" href="https://www.instagram.com/thebankofkorea" target="_blank" title="새창열림">
# <i class="ico-insta"></i>
# <span class="sr-only">한국은행 인스타그램  바로가기 (https://www.instagram.com/thebankofkorea)</span>
# </a>
# <a class="sns-twitter" href="https://www.twitter.com/bok_hub" target="_blank" title="새창열림">
# <i class="ico-x"></i>
# <span class="sr-only">한국은행 Twitter 바로가기 (https://www.twitter.com/bok_hub)</span>
# </a>
# </div>
# </div>
# </div>
# <script>
# 		//document.writeln("<img src='/portal/singl/siteConectStats/rcord.do?menuNo=200643&amp;conectUrlad=/portal/singl/baseRate/list.do?dataSeCd=01&menuNo=200643' border='0' width='0' height='0' alt='' />");
# 		$.ajax({
#             url: "/portal/singl/siteConectStats/rcord.do?menuNo=200643&conectUrlad=" + encodeURIComponent('/portal/singl/baseRate/list.do?dataSeCd=01&menuNo=200643'),
#             type: 'get',
#             async :true,
#             success: function (data) {}
#         })
# 	</script>
# </footer>
# <!-- //footer -->
# <script>
# $(document).ready(function () {
#
# 	$('.search_keyword').typeahead({
# 	    hint: false, // 나머지 글자가 자동으로 보여지는지
# 	    highlight: true,// 일치하는 문자 하이라이팅
# 	    minLength: 1    // 검색 시작하는 최소 문자 길이
# 	    , items :15
# 	    , limit :10
# 	    //,maxLength : 8
# 	    //,autoselect : true
# 	},
# 	{
# 	    limit :10, // 자동완성 목록에 보여질 개수
# 		name: 'tags',
# 	    source: function (query, syncResults, asyncResults) {
# 	        return $.ajax({
# 	            url: "/portal/ncloud/search/v1/domain/w3p-search2/document/search/autocomplete?type=section&item_count=10&query="+query,
# 	            //url: "/portal/ncloud/search/v1/domain/w3p-search2/document/search/autocomplete?type=term&item_count=15&query="+query,
# 	            type: 'get',
# 	            success: function (data) {
# 	                //console.log(data)
# 	                let item = data.responseData.result.items;
# 	                return asyncResults(item);  //asyncResults 에 배열을 넘기면 된다.
# 	            }
# 	        })
# 	    }
# 	  }
# 	);
#
# 	$("#topSearchFrm > div > button").click(function () {
# 		$("#topSearchFrm").submit();
# 	})
# });
# </script>
# <!-- 로그기록 END  -->
# <!-- <script type="text/javascript" src="/static/js/gongu/ms.bing.translate.js" charset="UTF-8"></script> -->
# </div>
# <script src="https://static-cdn.bok.or.kr/static/jslibrary/swiper@8/swiper-bundle.min.js"></script>
# <script src="https://static-cdn.bok.or.kr/static/portal/js/common.js"></script>
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-118968533-1"></script>
# <script src="https://spi.maps.daum.net/imap/map_js_init/postcode.v2.js"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-118968533-1');
#   //나중에 제외할 스크립트
#   $(document).ready(function () {
# 	  $(".video-tab button").each(function () {
# 		  if ($(this).attr("aria-selected") == 'true'){
# 			  $(this).attr('aria-selected', true).attr('title','선택됨').siblings().attr('aria-selected', false).removeAttr('title')
# 			  var _id = $(this).attr('id')
# 			  $('[aria-labelledby="' + _id + '"]').show().siblings().hide()
#
# 		  }
# 	  })
#   });
#
#   //자막, 내용 (접기, 펼치기)
#   $(".subtitle button").click(function(e){
# 	  $(this).removeClass("active");
# 	  if ($(this).attr("title")=="자막 닫기"){
# 		  $(this).toggleClass("active");
# 	  }
# 	  if ($(this).hasClass('active')){
# 		  $(this).attr("title", "자막 닫기");
# 	  } else {
# 		  $(this).attr("title", "자막 열기");
# 	  }
#   })
#   //다음 우편번호 찾기
#   function daumPostcodeSearch(zip,adres1) {
# 	  new daum.Postcode({
# 		  oncomplete : function(data) {
# 			  // 팝업에서 검색결과 항목을 클릭했을때 실행할 코드를 작성하는 부분.
#
# 			  // 도로명 주소의 노출 규칙에 따라 주소를 조합한다.
# 			  // 내려오는 변수가 값이 없는 경우엔 공백('')값을 가지므로, 이를 참고하여 분기 한다.
# 			  var fullRoadAddr = data.roadAddress; // 도로명 주소 변수
# 			  var extraRoadAddr = ''; // 도로명 조합형 주소 변수
#
# 			  // 법정동명이 있을 경우 추가한다. (법정리는 제외)
# 			  // 법정동의 경우 마지막 문자가 "동/로/가"로 끝난다.
# 			  if (data.bname !== '' && /[동|로|가]$/g.test(data.bname)) {
# 				  extraRoadAddr += data.bname;
# 			  }
# 			  // 건물명이 있고, 공동주택일 경우 추가한다.
# 			  if (data.buildingName !== '' && data.apartment === 'Y') {
# 				  extraRoadAddr += (extraRoadAddr !== '' ? ', ' + data.buildingName : data.buildingName);
# 			  }
# 			  // 도로명, 지번 조합형 주소가 있을 경우, 괄호까지 추가한 최종 문자열을 만든다.
# 			  if (extraRoadAddr !== '') {
# 				  extraRoadAddr = ' (' + extraRoadAddr + ')';
# 			  }
# 			  // 도로명, 지번 주소의 유무에 따라 해당 조합형 주소를 추가한다.
# 			  if (fullRoadAddr !== '') {
# 				  fullRoadAddr += extraRoadAddr;
# 			  }
#
# 			  // 우편번호와 주소 정보를 해당 필드에 넣는다.
# 			  document.getElementById(zip).value = data.zonecode; //5자리 새우편번호 사용
# 			  document.getElementById(adres1).value = fullRoadAddr;
# 		  }
# 	  }).open();
#   }
#
#
#   $("nav.container").find(".depth2").each(function(n) {
# 	if ($(this).find("ul>li").length == 0) {
# 		$(this).remove();
# 	}
#   });
#
#   $(".lnb-nav").find(".lnbDepth1").each(function(n) {
# 	if ($(this).children("ul").length > 0) {
#
# 		$(this).children("a").click(function() {
# 			$(".lnb-nav").find(".lnbDepth1").removeClass("on");
# 			$(this).closest("li").toggleClass("on");
# 			return false;
# 		});
# 	}
#   });
# </script>
# </body>
# </html>

# %%
int_soup.select_one('div.table tbody tr').text.split()
# Out:
# ['2023', '01월', '13일', '3.50']

# %%
import json

# %%
import json

# Specify the path to your JSON file
file_path = '.json'

# Read the JSON file
with open(file_path, 'r') as file:
    data = json.load(file)

# Get the length of the JSON data
length = len(data)

# Print the length
print(length)

# %%
url = "http://ars.yna.co.kr/api/v2/search.asis"
params = {
    "callback": "Search.SearchPreCallback",
    "query": "금리",
    "page_no": 2,
    "period": "diy",
    "from": "20140807",
    "to": "20240808",
    "ctype": "A",
    "page_size": 10,
    "channel": "basic_kr"
}
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}
response = requests.get(url, params=params, headers=headers, verify=False)
response.status_code
# Out:
# 200

# %%
yh_soup = bs(yh_res.text)
yh_soup
# Out:
# <!DOCTYPE HTML>
# <html class="ko" lang="ko">
# <head itemscope="">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, minimum-scale=1.0, user-scalable=no, target-densitydpi=medium-dpi" name="viewport"/>
# <meta content="noindex,nofollow" name="robots"/>
# <link href="https://www.yna.co.kr/search/index?query=%EA%B8%88%EB%A6%AC&amp;ctype=A&amp;from=20240607&amp;to=20240808&amp;period=diy&amp;page_no=2" id="canonical" rel="canonical"/>
# <meta content="https://www.yna.co.kr/search/index?query=%EA%B8%88%EB%A6%AC&amp;ctype=A&amp;from=20240607&amp;to=20240808&amp;period=diy&amp;page_no=2" property="og:url"/>
# <meta content="https://www.yna.co.kr/search/index?query=%EA%B8%88%EB%A6%AC&amp;ctype=A&amp;from=20240607&amp;to=20240808&amp;period=diy&amp;page_no=2" name="twitter:url"/>
# <meta content="https://www.yna.co.kr/search/index?query=%EA%B8%88%EB%A6%AC&amp;ctype=A&amp;from=20240607&amp;to=20240808&amp;period=diy&amp;page_no=2" itemprop="url"/>
# <title>금리 - 통합 검색 결과 | 연합뉴스</title>
# <meta content="금리 - 통합 검색 결과 | 연합뉴스" property="og:title"/>
# <meta content="금리 - 통합 검색 결과 | 연합뉴스" name="title"/>
# <meta content="금리 - 통합 검색 결과 | 연합뉴스" name="twitter:title"/>
# <meta content="금리 - 통합 검색 결과 | 연합뉴스" itemprop="name"/>
# <meta content="금리 - 통합 검색 결과 페이지 입니다." property="og:description"/>
# <meta content="금리 - 통합 검색 결과 페이지 입니다." name="description"/>
# <meta content="금리 - 통합 검색 결과 페이지 입니다." name="twitter:description"/>
# <meta content="금리 - 통합 검색 결과 페이지 입니다." itemprop="description"/>
# <meta content="website" property="og:type"/>
# <meta content="website" name="resource-type"/>
# <meta content="연합뉴스" property="og:site_name"/>
# <meta content="@yonhaptweet" name="twitter:site"/>
# <meta content="https://www.facebook.com/yonhap" property="article:publisher"/>
# <meta content="@yonhaptweet" name="twitter:creator"/>
# <meta content="ko_KR" property="og:locale"/>
# <meta content="ko_KR" itemprop="inLanguage"/>
# <meta content="https://www.facebook.com/yonhap" property="article:author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://r.yna.co.kr/global/home/v01/img/yonhapnews_logo_1200x800_kr01.jpg" name="twitter:image"/>
# <meta content="https://r.yna.co.kr/global/home/v01/img/yonhapnews_logo_1200x800_kr01.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="800" property="og:image:height"/>
# <meta content="https://r.yna.co.kr/global/home/v01/img/yonhapnews_logo_1200x800_kr01.jpg" name="image"/>
# <meta content="https://r.yna.co.kr/global/home/v01/img/yonhapnews_logo_1200x800_kr01.jpg" itemprop="image"/>
# <meta content="https://r.yna.co.kr/global/home/v01/img/yonhapnews_logo_1200x800_kr01.jpg" itemprop="thumbnailUrl"/>
# <meta content="IE=edge, chrome=1" http-equiv="X-UA-Compatible"/>
# <link href="https://r.yna.co.kr/global/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://r.yna.co.kr/global/favicon.ico" rel="icon" type="image/x-icon"/>
# <link href="https://r.yna.co.kr/www/home_n/v01/css/news2015.css?v=20240523_1421" rel="stylesheet"/>
# <link href="https://r.yna.co.kr/www/home/v01/css/inline_style.css" rel="stylesheet"/>
# <link href="https://r.yna.co.kr/global/home/v01/css/weather_ui.css?v=20240509_1142" rel="stylesheet"/>
# <link href="https://r.yna.co.kr/www/home_n/v01/css/weather.css?v=20240619_1030" rel="stylesheet"/>
# <link href="https://r.yna.co.kr/www/home_n/v01/css/search2013.css?v=20240116_1605" rel="stylesheet"/>
# <script src="https://rd.yna.co.kr/www/js/jquery-1.12.4.js" type="text/javascript"></script>
# <!--[if (IE 8)|(IE 9)]><script src="https://rd.yna.co.kr/common/js/jquery.xdr.min.js"></script><![endif]-->
# <script src="https://r.yna.co.kr/www/home_n/v01/js/jquery-ui.min.js" type="text/javascript"></script>
# <script src="https://r.yna.co.kr/www/home_n/v01/js/plugin.js" type="text/javascript"></script>
# <script src="https://rd.yna.co.kr/www/js/kr_static.js?v=20240619_1030" type="text/javascript"></script>
# <script src="https://r.yna.co.kr/www/home_n/v01/js/common.js?v=20240619_1030" type="text/javascript"></script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-3JKE3F58CD"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
# 	function gtag() { dataLayer.push(arguments); }
# 	gtag('js', new Date());
# 	gtag('config', 'G-3JKE3F58CD');
# </script>
# <script src="https://rd.yna.co.kr/global/js/yna_stat.js?v=20240619_1030" type="text/javascript"></script>
# <script src="https://r.yna.co.kr/global/lib/v01/js/nlogger.js" type="text/javascript"></script>
# <script type="text/javascript">
# // NLOGGER 로깅 설정
# nLogger.configure({
# 	nth_service_id: "www.yna.co.kr", // 로그 생성 단위, 값 지정 필요
# 	nth_logging_url_base_http: "http://wl.yna.co.kr/nlog", // 수집 서버 주소
# 	nth_logging_url_base_https: "https://wl.yna.co.kr/nlog" // 수집 서버 주소
# });
# // NLOGGER 기본 페이지뷰 로깅
# nLogger.log();
# </script>
# <script src="https://cdp.yna.co.kr/script/1.0.0/yna_crm_log_module.min.js"></script>
# <script>
# 	window.__YNALogModuleDataLayer = window.__YNALogModuleDataLayer || [];
# 	window.__YNALogModuleDataLayer.push({ type: 'pageview', option: { sid: 'YNA' } });
# </script>
# <script src="https://rd.yna.co.kr/global/js/ns.js?v=120240619_1030"></script>
# <script src="https://rd.yna.co.kr/global/js/search_basic.js?v=20240702_0927"></script>
# <script type="application/ld+json">
# {
# 	"@context": "https://schema.org","@type": "WebSite",
# 	"url": "https://www.yna.co.kr/",
# 	"@id": "https://www.yna.co.kr/#publisher",
# 	"potentialAction": [{"@type": "SearchAction","target": "https://www.yna.co.kr/search/index?query={query}","query-input": {"@type": "PropertyValueSpecification","valueRequired": true,"valueName": "query"}}]
# }
# </script>
# <script type="application/ld+json">
# {
# 	"@context": "https://schema.org","@type": "NewsMediaOrganization",
# 	"name" : "연합뉴스" ,"alternateName":  ["YNA", "YonhapNews", "Yonhap News Agency", "韩联社", "聯合ニュース", "وكالة يونهاب للانباء", "AGENCIA DE NOTICIAS YONHAP", "AGENCE DE PRESSE YONHAP"],
# 	"url": "https://www.yna.co.kr/",
# 	"@id": "https://www.yna.co.kr/#publisher",
# 	"logo": {"@context": "https://schema.org","@type": "ImageObject","url": "https://r.yna.co.kr/global/home/v01/img/yonhapnews_logo_600x600_kr01.jpg","width": 600,"height": 600},
# 	"image": {"@context": "http://schema.org","@type": "ImageObject","url": "https://r.yna.co.kr/global/home/v01/img/yonhapnews_logo_1200x800_kr01.jpg","width": 1200, "height": 800},
# 	"ethicsPolicy": "https://www.yna.co.kr/policy/ethics",
# 	"foundingDate": "1980-12-19",
# 	"address": {"@type": "PostalAddress", "postalCode": "03143", "addressCountry": "KR", "addressRegion": "서울특별시", "addressLocality": "종로구", "streetAddress": "율곡로2길 25"},"telephone": "+82-2-398-3114",
# 	"sameAs": ["https://www.facebook.com/yonhap","https://twitter.com/yonhaptweet","https://www.instagram.com/yonhap_news/","https://www.facebook.com/yonhapvideo/","https://www.youtube.com/channel/UCj3_t5p4L4aFsvdW3uHjnnw","https://www.youtube.com/channel/UCHzW_7Mf8G0JxP4b0LoAd7A","https://www.youtube.com/channel/UCR-L8oZkHzgDh1ahJhH2WDQ","https://www.youtube.com/channel/UChX-Cgkfava-G-LlfwC9v_g","https://ko.wikipedia.org/wiki/%EC%97%B0%ED%95%A9%EB%89%B4%EC%8A%A4"]
# }
# </script>
# <script type="application/ld+json">
# {
# 	"@context": "https://schema.org", "@type": "BreadcrumbList",
# 	"itemListElement": [
#
#
# 		{"@type": "ListItem","position": 1,"item": {"@id": "https://www.yna.co.kr/","name": "연합뉴스"}},
#
#
#
# 		{"@type": "ListItem","position": 2,"item": {"@id": "https://www.yna.co.kr/search/index","name": "검색"}}
#
#
#
#
#
# 	]
# }
# </script>
# <script src="https://rd.yna.co.kr/global/js/redirect.js" type="text/javascript"></script>
# <script>
# 	var checkIpad = (/(ipad)/i).test(navigator.userAgent) || (navigator.platform === 'MacIntel' && navigator.maxTouchPoints > 1);
# </script>
# <script>
# 	if(location.href.match("#mobile")) Redirect.checkIgnore();
# 	else if (checkIpad) window.location.href = '//m.yna.co.kr/search/index?query=금리';
# 	else Redirect.check('https://m.yna.co.kr/search/index?query=금리', '');
# </script>
# <script>
# $(document.body).ready(function () {
# 	$("#search_openapi").click(function () {
# 		var FULL_URL = "//" + window.location.host + "/search/openapi-partner?query="+Search.Options.query;
# 		console.log(FULL_URL);
# 		document.location.href = FULL_URL;
# 	});
# });
# </script>
# </head>
# <body class="search-page search2015-page">
# <div class="search_HdivLoad" id="HdivLoad">
# <div class="con">
# <p class="txt">Loading</p>
# <img alt="로딩중" class="img02" src="//r.yna.co.kr/www/home_n/v01/img/loading01.gif"/>
# </div>
# </div>
# <div class="sub-wrap gnb-news-01" id="wrap">
# <div id="header">
# <h2 class="title-search">검색</h2>
# <div class="top-logo">
# <span class="skip-link">
# <a href="#content">본문 바로가기</a>
# <a href="#search">검색 바로가기</a>
# <a href="#gnb">메뉴 바로가기</a>
# </span>
# <strong class="logo">
# <a href="https://www.yna.co.kr">국가기간뉴스통신사 연합뉴스<span></span></a>
# </strong>
# <div class="today today-weather">
# <span class="blind">날짜와 날씨</span>
# <span class="date" id="tickerWeatherDate">
# <strong> </strong>
# <em></em>
# </span>
# <div class="weather main-top-weather" id="tickerWeather">
# <a data-stat-code="header_weather" href="https://www.yna.co.kr/weather/index">
# <ul></ul>
# </a>
# </div>
# </div>
# </div>
# <div class="top-link-wrap">
# <div class="top-link">
# <div class="wholemenu-wrap">
# <button class="btn-wholemenu01" data-stat-code="header_wholemenu" type="button"><span>전체메뉴 열기</span></button>
# <div class="wholemenu" id="wholemenu">
# <span class="blind">전체메뉴</span>
# <div class="wholemenu-top-bg">
# <div class="wholemenu-top-wrap">
# <div class="wholemenu-top">
# <dl>
# <dt><a href="https://www.yna.co.kr/">뉴스 홈</a></dt>
# <dd><a href="https://www.yna.co.kr/news">최신기사</a></dd>
# <dd><a href="https://www.yna.co.kr/politics/index">정치</a></dd>
# <dd><a href="https://www.yna.co.kr/north-korea/all">북한</a></dd>
# <dd><a href="https://www.yna.co.kr/economy/index">경제</a></dd>
# <dd><a href="https://www.yna.co.kr/market-plus/index">마켓 +</a></dd>
# <dd><a href="https://www.yna.co.kr/industry/index">산업</a></dd>
# <dd><a href="https://www.yna.co.kr/society/index">사회</a></dd>
# <dd><a href="https://www.yna.co.kr/local/index">전국</a></dd>
# <dd><a href="https://www.yna.co.kr/international/index">세계</a></dd>
# <dd><a href="https://www.yna.co.kr/culture/index">문화</a></dd>
# <dd><a href="https://www.yna.co.kr/health/index">건강</a></dd>
# <dd><a href="https://www.yna.co.kr/entertainment/index">연예</a></dd>
# <dd><a href="https://www.yna.co.kr/sports/index">스포츠</a></dd>
# <dd><a href="https://www.yna.co.kr/opinion/index">오피니언</a></dd>
# <dd><a href="https://www.yna.co.kr/people/index">사람들</a></dd>
# </dl>
# </div>
# <div class="wholemenu-top">
# <dl>
# <dt><a href="https://www.yna.co.kr/local/index">전국</a></dt>
# <dd><a href="https://www.yna.co.kr/local/all">전체기사</a></dd>
# <dd><a href="https://www.yna.co.kr/local/gyeonggi/index">경기</a></dd>
# <dd><a href="https://www.yna.co.kr/local/incheon/index">인천</a></dd>
# <dd><a href="https://www.yna.co.kr/local/busan/index">부산</a></dd>
# <dd><a href="https://www.yna.co.kr/local/ulsan/index">울산</a></dd>
# <dd><a href="https://www.yna.co.kr/local/gyeongnam/index">경남</a></dd>
# <dd><a href="https://www.yna.co.kr/local/daegu-gyeongbuk/index">대구/경북</a></dd>
# <dd><a href="https://www.yna.co.kr/local/gwangju-jeonnam/index">광주/전남</a></dd>
# <dd><a href="https://www.yna.co.kr/local/jeonbuk/index">전북</a></dd>
# <dd><a href="https://www.yna.co.kr/local/daejeon-chungnam-sejong/index">대전/충남/세종</a></dd>
# <dd><a href="https://www.yna.co.kr/local/chungbuk/index">충북</a></dd>
# <dd><a href="https://www.yna.co.kr/local/gangwon/index">강원</a></dd>
# <dd><a href="https://www.yna.co.kr/local/jeju/index">제주</a></dd>
# </dl>
# </div>
# <div class="wholemenu-top">
# <dl>
# <dt><a href="https://www.yna.co.kr/sports/index">스포츠</a></dt>
# <dd><a href="https://www.yna.co.kr/sports/all">전체기사</a></dd>
# <dd><a href="https://www.yna.co.kr/sports/baseball">야구</a></dd>
# <dd><a href="https://www.yna.co.kr/sports/football">축구</a></dd>
# <dd><a href="https://www.yna.co.kr/sports/basketball-volleyball">농구/배구</a></dd>
# <dd><a href="https://www.yna.co.kr/sports/golf">골프</a></dd>
# </dl>
# <dl>
# <dt><a href="https://www.yna.co.kr/people/index">사람들</a></dt>
# <dd><a href="https://www.yna.co.kr/people/personnel">인사</a></dd>
# <dd><a href="https://www.yna.co.kr/people/obituary-notice">부고</a></dd>
# <dd><a href="https://www.yna.co.kr/people/movement">동정/게시판</a></dd>
# <dd><a href="https://www.yna.co.kr/people/ceo">CEO</a></dd>
# <dd><a href="https://www.yna.co.kr/people/interview">인터뷰</a></dd>
# <dd><a href="https://www.yna.co.kr/people/startup">스타트업 발언대</a></dd>
# </dl>
# </div>
# <div class="wholemenu-top">
# <dl>
# <dt><a href="https://www.yna.co.kr/international/index">세계</a></dt>
# <dd><a href="https://www.yna.co.kr/international/all">전체기사</a></dd>
# <dd><a href="https://www.yna.co.kr/international/correspondents/index">특파원</a></dd>
# <dd><a href="https://www.yna.co.kr/international/north-america">미국/북미</a></dd>
# <dd><a href="https://www.yna.co.kr/international/china">중국</a></dd>
# <dd><a href="https://www.yna.co.kr/international/japan">일본</a></dd>
# <dd><a href="https://www.yna.co.kr/international/asia-australia">아시아/호주</a></dd>
# <dd><a href="https://www.yna.co.kr/international/europe">유럽</a></dd>
# <dd><a href="https://www.yna.co.kr/international/centralsouth-america">중남미</a></dd>
# <dd><a href="https://www.yna.co.kr/international/middleeast-africa">중동/아프리카</a></dd>
# <dd><a href="https://www.yna.co.kr/international/international-org">국제기구</a></dd>
# </dl>
# </div>
# <div class="wholemenu-top">
# <div class="box">
# <p><a href="https://www.yna.co.kr/issue/index" rel="nofollow">이슈돋보기</a></p>
# </div>
# <div class="box">
# <p><a href="https://www.yna.co.kr/press-release/index" rel="nofollow" target="_blank" title="새창">보도자료</a></p>
# </div>
# <dl>
# <dt class="blind">주요신문/헤드라인</dt>
# <dd><a href="https://www.yna.co.kr/opinion/paper">주요신문 톱뉴스/사설</a></dd>
# <dd><a href="https://www.yna.co.kr/opinion/headline">이 시각 헤드라인</a></dd>
# </dl>
# <dl>
# <dt class="blind">재난/북한 포털</dt>
# <dd><a href="https://www.yna.co.kr/safe/index" rel="nofollow">재난포털</a></dd>
# <dd><a href="https://www.yna.co.kr/nk/index" rel="nofollow" target="_blank" title="새창">북한포털</a></dd>
# <dd><a href="https://www.yna.co.kr/weather/index" rel="nofollow">날씨</a></dd>
# </dl>
# <dl>
# <dt class="blind">SNS</dt>
# <dd><a href="https://twitter.com/yonhaptweet" rel="nofollow" target="_blank" title="새창">트위터</a></dd>
# <dd><a href="https://www.facebook.com/yonhap" rel="nofollow" target="_blank" title="새창">페이스북</a></dd>
# <dd><a href="https://story.kakao.com/ch/yonhapmedia" rel="nofollow" target="_blank" title="새창">카카오스토리</a></dd>
# </dl>
# </div>
# <div class="wholemenu-top">
# <dl>
# <dt><a href="https://www.yna.co.kr/visual/index">비주얼뉴스</a></dt>
# <dd><a href="https://www.yna.co.kr/video/index">영상</a></dd>
# <dd><a href="https://www.yna.co.kr/photo/index">포토</a></dd>
# <dd><a href="https://www.yna.co.kr/gallery/index">화보</a></dd>
# <dd><a href="https://www.yna.co.kr/digital/index">#D</a></dd>
# <dd><a href="https://www.yna.co.kr/graphic/index">그래픽</a></dd>
# </dl>
# </div>
# </div>
# </div>
# <div class="wholemenu-bot-wrap">
# <dl>
# <dt>테마별뉴스</dt>
# <dd><a href="https://www.yna.co.kr/theme/hotnews-history" rel="nofollow">핫뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/topnews-history" rel="nofollow">톱뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/headlines-history" rel="nofollow">주요뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/breaknews-history" rel="nofollow">긴급뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/exclusive" rel="nofollow">단독뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/mostviewed/index" rel="nofollow">많이본뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/long-stay-news/index" rel="nofollow">오래머문뉴스</a></dd>
# </dl>
# <input class="btn-close" type="button" value="전체메뉴 닫기"/>
# </div>
# </div>
# </div>
# <ul class="top-link01">
# <li><a href="//en.yna.co.kr" target="_blank" title="새창"><img alt="영어사이트" src="//img.yonhapnews.co.kr/basic/svc/14_images/lang_en.gif"/></a></li>
# <li><a href="//cn.yna.co.kr" target="_blank" title="새창"><img alt="중국어사이트" src="//img.yonhapnews.co.kr/basic/svc/14_images/lang_zh.gif"/></a></li>
# <li><a href="//jp.yna.co.kr" target="_blank" title="새창"><img alt="일본어사이트" src="//img.yonhapnews.co.kr/basic/svc/14_images/lang_ja.gif"/></a></li>
# <li><a href="//ar.yna.co.kr" target="_blank" title="새창"><img alt="아랍어사이트" src="//img.yonhapnews.co.kr/basic/svc/14_images/lang_ar.gif"/></a></li>
# <li><a href="//sp.yna.co.kr" target="_blank" title="새창"><img alt="스페인어사이트" src="//img.yonhapnews.co.kr/basic/svc/14_images/lang_es.gif"/></a></li>
# <li><a href="//fr.yna.co.kr" target="_blank" title="새창"><img alt="프랑스어사이트" src="//img.yonhapnews.co.kr/basic/svc/14_images/lang_fr.gif"/></a></li>
# </ul>
# <ul class="top-link02">
# <li class="newsY"><a href="https://www.yonhapnewstv.co.kr/" rel="nofollow" target="_blank" title="새창"><img alt="연합뉴스TV" src="https://img.yonhapnews.co.kr/basic/svc/14_images/nav_top_ynatv.gif"/></a></li>
# <li class="infomax"><a href="https://news.einfomax.co.kr/" rel="nofollow" target="_blank" title="새창"><img alt="인포맥스" src="https://img.yonhapnews.co.kr/basic/svc/14_images/nav_top_einfomax.gif"/></a></li>
# </ul>
# </div>
# </div>
# <div class="top-wrap" id="s_policy_gnb_box">
# <div class="search-zone" id="s_policy_gnb_box1">
# <div class="s_srvc_srch">
# <h2 class="blind">검색</h2>
# <fieldset>
# <p>
# <label class="blind">검색어</label>
# <span class="s_srchbar"><input id="keyword" name="" title="검색어입력" type="text"/></span>
# <button class="s_srchbtn" id="search_button" title="검색" type="button" value="confirm"><span class="blind">검색</span></button>
# </p>
# </fieldset>
# </div>
# <div class="wrap_s dis_none" id="suggest">
# <div class="words">
# </div>
# <p class="func"><span><a class="funoff" href="#">자동완성 끄기</a></span></p>
# </div>
# </div>
# <div class="gnb-wrap">
# <h2 class="blind">메뉴</h2>
# <ul class="gnb search_menu1">
# <li class="current btn_over" id="search_all"><a class="gnb-1dep" href="#none">통합검색</a></li>
# <li class="btn_over" id="search_article"><a class="gnb-1dep" href="#none">뉴스</a></li>
# <li class="btn_over" id="search_photo"><a class="gnb-1dep" href="#none">포토</a></li>
# <li class="btn_over" id="search_mpic"><a class="gnb-1dep" href="#none">영상</a></li>
# <li class="btn_over" id="search_issue"><a class="gnb-1dep" href="#none">이슈</a></li>
# <li class="btn_over" id="search_graphic"><a class="gnb-1dep" href="#none">그래픽</a></li>
# <li class="btn_over" id="search_people"><a class="gnb-1dep" href="#none">인물</a></li>
# <li class="btn_over" id="search_press"><a class="gnb-1dep" href="#none">보도자료</a></li>
# </ul>
# <button class="search_more02 arr01" id="search_openapi"><span class="color01">제휴사 검색</span></button>
# </div>
# </div>
# </div>
# <div class="contents" id="center_line">
# <div class="contents01" id="search_container">
# <div class="contents-box" id="search_left">
# <div class="search_navi_result dis_none">검색어 <span class="point"> </span>(으)로 검색했습니다. </div>
# <div class="HdivbbbLayer2 dis_none">
# <p class="word_area">연관검색어</p>
# <p class="word_area2"><a href=""></a><a href=""></a><a href=""></a><a href=""></a><a href=""></a><a href=""></a><a href=""></a><a href=""></a><a href=""></a><a href=""></a><a href=""></a><a href=""></a><a href=""></a><a href=""></a><a href=""></a></p>
# </div>
# <div class="search-detail-wrap" id="search_detail_inbox">
# <fieldset>
# <legend>상세 검색 영역</legend>
# <div class="form form-area01">
# <div class="zone srch-zone">
# <label class="tit-label" for="keyword2">검색어</label>
# <input class="text1 wid340" id="keyword2" type="text"/>
# </div>
# <div class="zone writer-zone">
# <label class="tit-label" for="writer">기자명</label>
# <input class="text1 wid90" id="writer" type="text"/>
# </div>
# </div>
# <div class="form form-area02">
# <div class="zone contents-zone">
# <span class="tit-label">검색영역</span>
# <span class="label-wrap"><label for="srchAreaAll">전체</label><input checked="checked" class="radio1" id="srchAreaAll" name="scope" type="radio" value=""/></span>
# <span class="label-wrap"><label for="srchAreaTitle">제목</label><input checked="checked" class="radio1" id="srchAreaTitle" name="scope" type="radio" value="title"/></span>
# <span class="label-wrap"><label for="srchAreaText">본문</label><input checked="checked" class="radio1" id="srchAreaText" name="scope" type="radio" value="text_body"/></span>
# </div>
# <div class="zone align-zone">
# <span class="tit-label">정렬</span>
# <span class="label-wrap"><label for="srchAlign01">최신순</label><input checked="checked" class="radio1" id="srchAlign01" name="sort" type="radio" value="date"/></span>
# <span class="label-wrap"><label for="srchAlign02">정확도순</label><input class="radio1" id="srchAlign02" name="sort" type="radio" value="weight"/></span>
# </div>
# <div class="zone choice-zone">
# <span class="tit-label">검색분야</span>
# <div class="jqTransformSelectWrapper" id="div_code">
# <div class="con">
# <span class="jqform_m_b10">복수선택가능</span>
# <a class="jqTransformSelectOpen" href=""></a>
# </div>
# <ul class="jqfunc dis_none" id="div_list">
# <li><input id="div_all" type="checkbox"/><label class="label" for="div_all">전체</label></li>
# <li><input id="srchCate01" name="div_code" type="checkbox" value="01"/><label class="label" for="srchCate01">정치</label></li>
# <li><input id="srchCate02" name="div_code" type="checkbox" value="02"/><label class="label" for="srchCate02">경제 </label></li>
# <li><input id="srchCate03" name="div_code" type="checkbox" value="05"/><label class="label" for="srchCate03">사회</label></li>
# <li><input id="srchCate04" name="div_code" type="checkbox" value="03,04"/><label class="label" for="srchCate04">금융증권산업</label></li>
# <li><input id="srchCate05" name="div_code" type="checkbox" value="06"/><label class="label" for="srchCate05">사건사고</label></li>
# <li><input id="srchCate06" name="div_code" type="checkbox" value="07"/><label class="label" for="srchCate06">문화</label></li>
# <li><input id="srchCate07" name="div_code" type="checkbox" value="08"/><label class="label" for="srchCate07">생활건강</label></li>
# <li><input id="srchCate08" name="div_code" type="checkbox" value="09"/><label class="label" for="srchCate08">IT과학</label></li>
# <li><input id="srchCate09" name="div_code" type="checkbox" value="10"/><label class="label" for="srchCate09">북한</label></li>
# <li><input id="srchCate10" name="div_code" type="checkbox" value="11"/><label class="label" for="srchCate10">국제</label></li>
# <li><input id="srchCate11" name="div_code" type="checkbox" value="12"/><label class="label" for="srchCate11">스포츠</label></li>
# <li><input id="srchCate12" name="div_code" type="checkbox" value="0712"/><label class="label" for="srchCate12">연예</label></li>
# <li><input id="srchCate13" name="div_code" type="checkbox" value="13"/><label class="label" for="srchCate13">기타</label></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="form form-area03">
# <div class="zone period-zone">
# <span class="tit-label">검색기간</span>
# <span class="label-wrap"><label for="periodAll">전체</label><input checked="checked" class="radio1" id="periodAll" name="period" type="radio" value="all"/></span>
# <span class="label-wrap"><label for="perioddd">1일</label><input class="radio1" id="perioddd" name="period" type="radio" value="0d"/></span>
# <span class="label-wrap"><label for="periodweek">1주</label><input class="radio1" id="periodweek" name="period" type="radio" value="1w"/></span>
# <span class="label-wrap"><label for="periodmm">1개월</label><input class="radio1" id="periodmm" name="period" type="radio" value="1m"/></span>
# <span class="label-wrap"><label for="periodyy">1년</label><input class="radio1" id="periodyy" name="period" type="radio" value="1y"/></span>
# <span class="label-wrap">
# <label for="perioddirect">직접입력</label><input class="radio1" id="perioddirect" name="period" type="radio" value="diy"/>
# </span>
# <span class="enter-con">
# <input class="search_text text1" id="from" name="from" style="width:58px" type="text"/> ~ <input class="search_text text1" id="to" name="to" style="width:58px" type="text1"/>
# <span class="txt-memo03">예: 20240101</span>
# </span>
# </div>
# <div class="zone desc-zone">
# <p class="txt-memo02">뉴스 검색 범위는 최근 10년입니다.</p>
# </div>
# </div>
# <div class="form form-area04">
# <button class="search_button1" id="search_click" type="button"><span>검색</span></button>
# </div>
# </fieldset>
# </div>
# <div class="search_news_list dis_none" id="article_list">
# <div class="search_news_list_title">
# <h3 class="title ico01">뉴스</h3><span class="total"></span>
# <span class="search_more dis_none"><a href="#none" title="더 많은 기사 보기">더보기</a></span>
# <span class="txt-mes01 hide result-none">검색 결과가 없습니다.</span>
# <span class="txt-mes02">검색 범위는 최근 10년입니다.</span>
# </div>
# <div class="cts_atclst">
# </div>
# </div>
# <div class="paging_search dis_none">
# <a class="prev" href="#"></a>
# <a class="bbb" href="#">1</a>
# <a href="#">2</a>
# <a class="next" href="#"></a>
# </div>
# <div class="search_pho_list_list dis_none" id="photo_list">
# <div class="search_news_list_title">
# <h3 class="title ico02">포토</h3><span class="total"></span>
# <span class="search_more dis_none"><a href="#none" title="더 많은 사진 보기">더보기</a></span>
# <span class="txt-mes01 hide result-none">검색 결과가 없습니다.</span>
# <span class="txt-mes02">검색 범위는 최근 1주일입니다.</span>
# </div>
# <div id="photo_list_2">
# </div>
# <div class="banner-hp01">
# <a href="https://www.helloarchive.co.kr/" target="_blank" title="새창"><img alt="헬로아카이브, 국내 최고의 콘텐츠 판매 플랫폼" src="//r.yna.co.kr/ad/img/2022/bnr_hello_archive01.jpg"/></a>
# </div>
# </div>
# <div class="paging_search dis_none">
# <a class="prev" href="#"></a>
# <a class="bbb" href="#">1</a>
# <a href="#">2</a>
# <a class="next" href="#"></a>
# </div>
# <div class="search_pho_list_list dis_none" id="mpic_list">
# <div class="search_news_list_title">
# <h3 class="title ico03">영상</h3><span class="total"></span>
# <span class="search_more dis_none"><a href="#none" title="더 많은 영상 보기">더보기</a></span>
# <span class="txt-mes01 hide result-none">검색 결과가 없습니다.</span>
# <span class="txt-mes02">검색 범위는 최근 1주일입니다.</span>
# </div>
# <div id="mpic_list_2">
# </div>
# </div>
# <div class="paging_search dis_none">
# <a class="prev" href="#"></a>
# <a class="bbb" href="#">1</a>
# <a href="#">2</a>
# <a class="next" href="#"></a>
# </div>
# <div class="search_pho_list_list dis_none" id="graphic_list">
# <div class="search_news_list_title">
# <h3 class="title ico04">그래픽</h3><span class="total"></span>
# <span class="search_more dis_none"><a href="#none" title="더 많은 그래픽 보기">더보기</a></span>
# <span class="txt-mes01 hide result-none">검색 결과가 없습니다.</span>
# </div>
# <div id="graphic_list_2">
# </div>
# </div>
# <div class="paging_search dis_none">
# <a class="prev" href="#"></a>
# <a class="bbb" href="#">1</a>
# <a href="#">2</a>
# <a class="next" href="#"></a>
# </div>
# <div class="issue_news_list dis_none" id="people_list">
# <div class="search_news_list_title">
# <h3 class="title ico05">인물</h3><span class="total"></span>
# <span class="search_more"><a href="#none" title="더 많은 인물 보기">더보기</a></span>
# <span class="txt-mes01 hide result-none">검색 결과가 없습니다.</span>
# </div>
# <div id="people">
# </div>
# </div>
# <div class="paging_search dis_none">
# <a class="prev" href="#"></a>
# <a class="bbb" href="#">1</a>
# <a href="#">2</a>
# <a class="next" href="#"></a>
# </div>
# <div class="issue_news_list dis_none" id="issue_list">
# <div class="search_news_list_title">
# <h3 class="title ico06">이슈</h3><span class="total"></span>
# <span class="search_more dis_none"><a href="#none" title="더 많은 이슈 보기">더보기</a></span>
# <span class="txt-mes01 hide result-none">검색 결과가 없습니다.</span>
# </div>
# <div class="issue_lists" id="issue_lists">
# </div>
# </div>
# <div class="paging_search dis_none">
# <a class="prev" href="#"></a>
# <a class="bbb" href="#">1</a>
# <a href="#">2</a>
# <a class="next" href="#"></a>
# </div>
# <div class="search_news_list02 dis_none" id="press_list">
# <div class="search_news_list_title">
# <h3 class="title ico07">보도자료</h3><span class="total"></span>
# <span class="search_more dis_none"><a href="#none" title="더 많은 보도자료 보기">더보기</a></span>
# <span class="txt-mes01 hide result-none">검색 결과가 없습니다.</span>
# </div>
# <div id="press_list_2">
# </div>
# </div>
# <div class="paging_search dis_none">
# <a class="prev" href="#"></a>
# <a class="bbb" href="#">1</a>
# <a href="#">2</a>
# <a class="next" href="#"></a>
# </div>
# <div class="bottom_arrow">
# <a class="before" href="javascript:window.history.back();">이전</a>
# </div>
# </div>
# </div>
# <div class="contents02">
# <div class="bnr-box01 online-sales">
# <h2 class="blind">광고</h2>
# <div>
# <a href="https://mnu.yna.co.kr/mnu/apply" rel="nofollow">
# <img alt="온라인 판매 페이지" src="//r.yna.co.kr/ad/img/2023/bnr_search01_search.jpg"/>
# </a>
# </div>
# </div>
# <div class="contents-box goolge-banner">
# <h2 class="blind">광고</h2>
# <div>
# <script type="text/javascript">
# <!--
# google_ad_client = "ca-pub-1728051424180693";
# /* 검색_우측 상단(250&#42;250) */
# google_ad_slot = "4148790797";
# google_ad_width = 250;
# google_ad_height = 250;
# //-->
# </script>
# <script src="//pagead2.googlesyndication.com/pagead/show_ads.js" type="text/javascript"></script>
# </div>
# </div>
# <iframe class="ifm-hot-news" frameborder="0" height="370" name="ifm-hot-news" scrolling="no" src="//www.yna.co.kr/program/hot-news" title="핫뉴스 프레임" width="340"></iframe>
# <div class="contents-box list-style01 popularnews-zone">
# <h5 class="tit-type01" data-stat-code="box_popularnews_tit"><a href="https://www.yna.co.kr/theme/mostviewed/index" target="_top">많이 본 뉴스</a></h5>
# <h5 class="tit-type03" data-stat-code="box_popularnews_tit"><a href="https://www.yna.co.kr/theme/mostviewed/index" target="_top">많이 본 뉴스</a></h5>
# <div class="tab-wrap01 tab-setting" data-stat-code="box_popularnews_tab">
# <ul>
# <li><a href="#popularTotal">종합</a></li>
# <li><a href="#popularPolitics">정치</a></li>
# <li><a href="#popularEconomy">경제</a></li>
# <li><a href="#popularSociety">사회</a></li>
# <li><a href="#popularLocal">전국</a></li>
# <li><a href="#popularSports">스포츠</a></li>
# <li><a href="#popularWorld">세계</a></li>
# </ul>
# <input class="btn_prev" type="button" value="이전 탭 보기"/>
# <input class="btn_next" type="button" value="다음 탭 보기"/>
# </div>
# <div class="list-wrap" id="popularTotal">
# <h6 class="hidden-obj">종합</h6>
# <ul>
# </ul>
# </div>
# <div class="list-wrap" id="popularPolitics">
# <h6 class="hidden-obj">정치</h6>
# <ul>
# </ul>
# </div>
# <div class="list-wrap" id="popularEconomy">
# <h6 class="hidden-obj">경제</h6>
# <ul>
# </ul>
# </div>
# <div class="list-wrap" id="popularSociety">
# <h6 class="hidden-obj">사회</h6>
# <ul>
# </ul>
# </div>
# <div class="list-wrap" id="popularLocal">
# <h6 class="hidden-obj">전국</h6>
# <ul>
# </ul>
# </div>
# <div class="list-wrap" id="popularSports">
# <h6 class="hidden-obj">스포츠</h6>
# <ul>
# </ul>
# </div>
# <div class="list-wrap" id="popularWorld">
# <h6 class="hidden-obj">세계</h6>
# <ul>
# </ul>
# </div>
# <a class="btn_more" data-stat-code="box_popularnews_btn_more" href="https://www.yna.co.kr/theme/mostviewed/index" target="_top" title="많이 본 뉴스 더보기">더보기</a>
# </div>
# <script src="https://rd.yna.co.kr/www/js/009900120000.js"></script>
# <iframe class="iframe-todaynews" frameborder="0" name="ifm-todaynews" scrolling="no" src="/program/major-news" title="오늘의 주요 뉴스"></iframe>
# <div class="contents-box list-style03" id="popularPhotoWrap">
# <h5 class="tit-type03" data-stat-code="box_popularphoto_tit"><span class="arr">많이 본 포토</span></h5>
# <div>
# <ul class="popularphoto">
# <li class="sector">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240816015900062">
# <span>
# <img alt="경포해수욕장의 독성 해파리" src="https://img8.yna.co.kr/photo/yna/YH/2024/08/16/PYH2024081601590006200_T.jpg"/>
# </span>
# <strong>경포해수욕장의 독성 해파리</strong>
# </a>
# </li>
# <li class="sector mg-none">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240815052900013">
# <span>
# <img alt="제79주년 광복절 기념 타종식" src="https://img3.yna.co.kr/photo/yna/YH/2024/08/15/PYH2024081505290001300_T.jpg"/>
# </span>
# <strong>제79주년 광복절 기념 타종식</strong>
# </a>
# </li>
# </ul>
# <ul class="popularphoto">
# <li class="sector">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240815092700013">
# <span>
# <img alt="언제까지 열대야..." src="https://img7.yna.co.kr/photo/yna/YH/2024/08/15/PYH2024081509270001300_T.jpg"/>
# </span>
# <strong>언제까지 열대야...</strong>
# </a>
# </li>
# <li class="sector mg-none">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240816005800042">
# <span>
# <img alt="북한 수해지역 주민들 평양도착" src="https://img4.yna.co.kr/photo/yna/YH/2024/08/16/PYH2024081600580004200_T.jpg"/>
# </span>
# <strong>북한 수해지역 주민들 평양도착</strong>
# </a>
# </li>
# </ul>
# <ul class="popularphoto">
# <li class="sector">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240815071900013">
# <span>
# <img alt="광복절 경축 공연하는 어린이뮤지컬단" src="https://img6.yna.co.kr/photo/yna/YH/2024/08/15/PYH2024081507190001300_T.jpg"/>
# </span>
# <strong>광복절 경축 공연하는 어린이뮤지컬단</strong>
# </a>
# </li>
# <li class="sector mg-none">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240815010500013">
# <span>
# <img alt="효창공원에서 '대한독립만세' 외치는 민주당 의원들" src="https://img9.yna.co.kr/photo/yna/YH/2024/08/15/PYH2024081501050001300_T.jpg"/>
# </span>
# <strong>효창공원에서 '대한독립만세' 외치는 민주당 의원들</strong>
# </a>
# </li>
# </ul>
# <ul class="popularphoto">
# <li class="sector">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240815058600013">
# <span>
# <img alt="군복 입고 야스쿠니신사 앞 행진하는 사람들" src="https://img6.yna.co.kr/photo/yna/YH/2024/08/15/PYH2024081505860001300_T.jpg"/>
# </span>
# <strong>군복 입고 야스쿠니신사 앞 행진하는 사람들</strong>
# </a>
# </li>
# <li class="sector mg-none">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240815022000013">
# <span>
# <img alt="자랑스러운 태극기 앞에" src="https://img5.yna.co.kr/photo/yna/YH/2024/08/15/PYH2024081502200001300_T.jpg"/>
# </span>
# <strong>자랑스러운 태극기 앞에</strong>
# </a>
# </li>
# </ul>
# <ul class="popularphoto">
# <li class="sector">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240816082900051">
# <span>
# <img alt="로봇과 치열한 바둑 한판" src="https://img4.yna.co.kr/photo/yna/YH/2024/08/16/PYH2024081608290005100_T.jpg"/>
# </span>
# <strong>로봇과 치열한 바둑 한판</strong>
# </a>
# </li>
# <li class="sector mg-none">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240815008500013">
# <span>
# <img alt="2024 광복RUN" src="https://img4.yna.co.kr/photo/yna/YH/2024/08/15/PYH2024081500850001300_T.jpg"/>
# </span>
# <strong>2024 광복RUN</strong>
# </a>
# </li>
# </ul>
# <ul class="popularphoto">
# <li class="sector">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240816129700013">
# <span>
# <img alt="계속 이어지는 열대야" src="https://img6.yna.co.kr/photo/yna/YH/2024/08/16/PYH2024081612970001300_T.jpg"/>
# </span>
# <strong>계속 이어지는 열대야</strong>
# </a>
# </li>
# <li class="sector mg-none">
# <a data-stat-code="box_popularphoto" href="https://www.yna.co.kr/view/PYH20240816102200063">
# <span>
# <img alt='"가을 온 느낌"…태안 수목원에 팜파스그라스 활짝' src="https://img3.yna.co.kr/photo/yna/YH/2024/08/16/PYH2024081610220006300_T.jpg"/>
# </span>
# <strong>"가을 온 느낌"…태안 수목원에 팜파스그라스 활짝</strong>
# </a>
# </li>
# </ul>
# </div>
# <span class="page-nation">0/0</span>
# <input class="btn_prev" data-stat-code="box_popularphoto_btn_dir" type="button" value="이전 사진보기"/>
# <input class="btn_next" data-stat-code="box_popularphoto_btn_dir" type="button" value="다음 사진보기"/>
# </div>
# <script src="https://rd.yna.co.kr/www/js/1203.js"></script>
# </div>
# </div>
# <span class="btn-top" id="btnScrollTop">
# <button type="button">맨위로</button>
# </span>
# <div id="footer">
# <div class="footer-wrap01 service-wrap">
# <span class="blind">전체메뉴</span>
# <div class="footer-menu01">
# <div class="menu-zone01">
# <div class="link-con">
# <dl class="list01">
# <dt class="tit"><a href="https://www.yna.co.kr/">뉴스 홈</a></dt>
# <dd><a href="https://www.yna.co.kr/news">최신기사</a></dd>
# <dd><a href="https://www.yna.co.kr/politics/index">정치</a></dd>
# <dd><a href="https://www.yna.co.kr/north-korea/all">북한</a></dd>
# <dd><a href="https://www.yna.co.kr/economy/index">경제</a></dd>
# <dd><a href="https://www.yna.co.kr/market-plus/index">마켓 +</a></dd>
# <dd><a href="https://www.yna.co.kr/industry/index">산업</a></dd>
# <dd><a href="https://www.yna.co.kr/society/index">사회</a></dd>
# <dd><a href="https://www.yna.co.kr/local/index">전국</a></dd>
# <dd><a href="https://www.yna.co.kr/international/index">세계</a></dd>
# <dd><a href="https://www.yna.co.kr/culture/index">문화</a></dd>
# <dd><a href="https://www.yna.co.kr/health/index">건강</a></dd>
# <dd><a href="https://www.yna.co.kr/entertainment/index">연예</a></dd>
# <dd><a href="https://www.yna.co.kr/sports/index">스포츠</a></dd>
# <dd><a href="https://www.yna.co.kr/opinion/index">오피니언</a></dd>
# <dd><a href="https://www.yna.co.kr/people/index">사람들</a></dd>
# </dl>
# </div>
# </div>
# <div class="menu-zone02">
# <div class="box">
# <div class="link-con">
# <dl class="list01">
# <dt class="tit"><a href="https://www.yna.co.kr/people/index">사람들</a></dt>
# <dd><a href="https://www.yna.co.kr/people/personnel">인사</a></dd>
# <dd><a href="https://www.yna.co.kr/people/obituary-notice">부고</a></dd>
# <dd><a href="https://www.yna.co.kr/people/movement">동정</a></dd>
# <dd><a href="https://www.yna.co.kr/people/ceo">CEO</a></dd>
# <dd><a href="https://www.yna.co.kr/people/interview">인터뷰</a></dd>
# </dl>
# </div>
# <div class="link-con">
# <dl class="list01">
# <dt class="tit"><a href="https://www.yna.co.kr/visual/index">비주얼뉴스</a></dt>
# <dd><a href="https://www.yna.co.kr/video/index">영상</a></dd>
# <dd><a href="https://www.yna.co.kr/photo/index">포토</a></dd>
# <dd><a href="https://www.yna.co.kr/gallery/index">화보</a></dd>
# <dd><a href="https://www.yna.co.kr/digital/index">#D</a></dd>
# <dd><a href="https://www.yna.co.kr/graphic/index">그래픽</a></dd>
# </dl>
# </div>
# <div class="link-con">
# <dl class="list01">
# <dt class="tit"><a href="https://www.yna.co.kr/issue/index" rel="nofollow">이슈돋보기</a></dt>
# <dd><a href="https://www.yna.co.kr/opinion/headline">이 시각 헤드라인</a></dd>
# </dl>
# <div class="list01">
# <dl class="list01">
# <dt class="hidden-obj">재난/북한 포털</dt>
# <dd><a href="https://www.yna.co.kr/safe/index" rel="nofollow">재난포털</a></dd>
# <dd><a href="https://www.yna.co.kr/nk/index" rel="nofollow" target="_blank" title="새창">북한포털</a></dd>
# <dd><a href="https://www.yna.co.kr/weather/index" rel="nofollow">날씨</a></dd>
# </dl>
# </div>
# </div>
# <div class="link-con">
# <dl class="list01">
# <dt class="tit">테마별뉴스</dt>
# <dd><a href="https://www.yna.co.kr/theme/hotnews-history" rel="nofollow">핫뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/topnews-history" rel="nofollow">톱뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/headlines-history" rel="nofollow">주요뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/breaknews-history" rel="nofollow">긴급뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/exclusive" rel="nofollow">단독뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/mostviewed/index" rel="nofollow">많이본뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/theme/long-stay-news/index" rel="nofollow">오래머문뉴스</a></dd>
# </dl>
# </div>
# <div class="link-con">
# <dl class="list01">
# <dt class="tit"><a href="https://www.yna.co.kr/mobile-service/index" rel="nofollow">모바일 뉴스</a></dt>
# <dd><a href="https://www.yna.co.kr/mobile-service/index#appTitleBox" rel="nofollow">모바일앱</a></dd>
# <dd><a href="https://www.yna.co.kr/mobile-service/index#webTitleBox" rel="nofollow">모바일웹</a></dd>
# </dl>
# <dl class="list01">
# <dt class="hidden-obj">비주얼뉴스</dt>
# </dl>
# </div>
# <div class="link-con">
# <dl class="list01">
# <dt class="tit">외국어</dt>
# <dd><a href="https://en.yna.co.kr">English</a></dd>
# <dd><a href="https://cn.yna.co.kr">中文</a></dd>
# <dd><a href="https://jp.yna.co.kr">日本語</a></dd>
# <dd><a href="https://ar.yna.co.kr">عربي</a></dd>
# <dd><a href="https://sp.yna.co.kr">Español</a></dd>
# <dd><a href="https://fr.yna.co.kr">Français</a></dd>
# </dl>
# </div>
# </div>
# <div class="box">
# <div class="link-con">
# <dl class="list01">
# <dt class="tit"><a href="https://www.yna.co.kr/product/premium" rel="nofollow">뉴스 상품</a></dt>
# <dd><a href="https://www.yna.co.kr/product/premium" rel="nofollow">프리미엄뉴스</a></dd>
# <dd><a href="https://www.yna.co.kr/product/newsleader" rel="nofollow">뉴스리더</a></dd>
# <dd><a href="https://www.yna.co.kr/product/personalisation" rel="nofollow">인터넷 맞춤형</a></dd>
# <dd><a href="https://www.yna.co.kr/product/press-release" rel="nofollow">보도자료 해외배포</a></dd>
# <dd><a href="https://www.yna.co.kr/press-release/index" rel="nofollow">보도자료 국내배포</a></dd>
# </dl>
# </div>
# <div class="link-con">
# <dl class="list01">
# <dt class="tit">출판물</dt>
# <dd><a href="https://www.yna.co.kr/imazine/index" rel="nofollow">이매진</a></dd>
# <dd><a href="https://yearbook.yonhapnews.co.kr/" rel="nofollow" target="_blank" title="새창">연합연감</a></dd>
# <dd><a href="https://www.yna.co.kr/publication/koreaannual" rel="nofollow">영문연감</a></dd>
# <dd><a href="https://www.yna.co.kr/publication/book" rel="nofollow">단행본</a></dd>
# <dd><a href="http://www.yonhapmidas.com/" rel="nofollow" target="_blank" title="새창">월간 마이더스</a>
# </dd>
# </dl>
# </div>
# <div class="link-con">
# <dl class="list01">
# <dt class="tit"><a href="https://www.yna.co.kr/advertisement/ktx" rel="nofollow">광고</a></dt>
# <dd><a href="https://www.yna.co.kr/advertisement/ktx" rel="nofollow">KTX열차</a></dd>
# <dd><a href="https://www.yna.co.kr/advertisement/arex" rel="nofollow">AREX 공항철도</a></dd>
# <dd><a href="https://www.yna.co.kr/advertisement/mobile" rel="nofollow">모바일</a></dd>
# <dd><a href="https://www.yna.co.kr/advertisement/pc" rel="nofollow">PC/홈페이지</a></dd>
# <dd><a href="https://www.yna.co.kr/advertisement/publication" rel="nofollow">출판물</a></dd>
# </dl>
# </div>
# <div class="link-con">
# <dl class="list01">
# <dt class="tit"><a href="https://www.helloarchive.co.kr/" rel="nofollow" target="_blank" title="새창">콘텐츠 판매</a>
# </dt>
# <dd><a href="https://www.helloarchive.co.kr/press/" rel="nofollow" target="_blank" title="새창">보도사진</a></dd>
# <dd><a href="https://www.helloarchive.co.kr/image/" rel="nofollow" target="_blank" title="새창">이미지</a></dd>
# <dd><a href="https://www.helloarchive.co.kr/graphic/" rel="nofollow" target="_blank" title="새창">그래픽</a></dd>
# <dd><a href="https://www.helloarchive.co.kr/movie/" rel="nofollow" target="_blank" title="새창">동영상</a></dd>
# <dd><a href="https://www.helloarchive.co.kr/person/" rel="nofollow" target="_blank" title="새창">인물</a></dd>
# </dl>
# </div>
# <div class="link-con">
# <dl class="list01">
# <dt class="tit">관련사이트</dt>
# <dd><a href="https://www.koreancenter.or.kr" rel="nofollow" target="_blank" title="새창">글로벌코리아본부</a></dd>
# <dd class="br"><a href="https://korean-vibe.com/" rel="nofollow" target="_blank" title="새창">K-VIBE</a></dd>
# <dd><a href="https://recruit.yna.co.kr/" rel="nofollow" target="_blank" title="새창">채용</a></dd>
# <dd><a href="https://www.yna.co.kr/irclub/index" rel="nofollow">IR 클럽</a></dd>
# </dl>
# </div>
# <div class="link-con">
# <dl class="list02">
# <dt class="tit">유튜브</dt>
# <dd class="yna"><a href="https://www.youtube.com/channel/UCj3_t5p4L4aFsvdW3uHjnnw" rel="nofollow" target="_blank" title="새창">연합뉴스</a></dd>
# <dd class="tong"><a href="https://www.youtube.com/channel/UCHzW_7Mf8G0JxP4b0LoAd7A" rel="nofollow" target="_blank" title="새창">통통컬처</a></dd>
# <dd class="kn"><a href="https://www.youtube.com/channel/UCR-L8oZkHzgDh1ahJhH2WDQ" rel="nofollow" target="_blank" title="새창">Korea Now</a></dd>
# </dl>
# </div>
# </div>
# </div>
# </div>
# <div class="footer-menu02">
# <a href="https://www.yna.co.kr/policy/partner" rel="nofollow">계약사/제휴문의</a>
# </div>
# </div>
# <ul class="footer-link" data-stat-code="footer">
# <li><a data-stat-code="footer_aboutus" href="https://www.yna.co.kr/aboutus/index" rel="nofollow">회사소개</a></li>
# <li><a data-stat-code="footer_policy_ethics" href="https://www.yna.co.kr/policy/ethics" rel="nofollow">윤리헌장</a></li>
# <li><a data-stat-code="footer_copyright" href="https://www.yna.co.kr/policy/copyright" rel="nofollow">저작권규약</a></li>
# <li><a data-stat-code="footer_user_committee" href="https://bbs.yna.co.kr/user/list" rel="nofollow">수용자권익위원회</a></li>
# <li><a data-stat-code="footer_advisory_committee" href="https://www.yna.co.kr/policy/contents" rel="nofollow">콘텐츠자문위원회</a></li>
# <li><a data-stat-code="footer_ombudsman" href="https://www.yna.co.kr/policy/complaint" rel="nofollow">고충처리</a></li>
# <li><a data-stat-code="footer_policy_terms" href="https://www.yna.co.kr/policy/terms/index" rel="nofollow">이용약관</a></li>
# <li><a data-stat-code="footer_policy_privacy" href="https://www.yna.co.kr/policy/privacy/index" rel="nofollow"><strong class="fw-b">개인정보처리방침</strong></a></li>
# <li><a data-stat-code="footer_bbs_reader" href="https://bbs.yna.co.kr/reader/list" rel="nofollow">독자게시판</a></li>
# <li><a data-stat-code="footer_jebo" href="https://www.yna.co.kr/board/jebo/index" rel="nofollow"><strong>기사제보(02-398-3000)</strong></a></li>
# <li><a data-stat-code="footer_rss" href="https://www.yna.co.kr/rss/index">RSS</a></li>
# <li><a data-stat-code="footer_sitemap" href="https://www.yna.co.kr/sitemap/index">사이트맵</a></li>
# </ul>
# <div class="addr-info">
# <address>연합뉴스 서울시 종로구 율곡로2길 25 | 등록번호 문화, 나00009 | 등록일자 1980.12.29 | 발행일자 1980.12.29 | Tel. 02-398-3114</address>
# </div>
# <ul class="copy">
# <li><strong>(C) Yonhapnews</strong></li>
# <li class="copy-in">[대표이사] 성기홍</li>
# </ul>
# </div>
# </div>
# <script src="https://rd.yna.co.kr/www/js/7091000000.js"></script>
# <script id="siteJsonData">
# (function(){
# 	SITE_DATA = JSON.stringify({
# 		"SITE_ID":"008100000000",
# 		"SITE_DEPTH":"1",
# 		"SITE1_LINK":"/search/index",
# 		"SITE1_LINK_NAME01":"search",
# 		"SITE1_NAME":"검색",
# 		"SITE2_LINK":"",
# 		"SITE2_NAME":"",
# 		"SITE3_LINK":"",
# 		"SITE3_NAME":"",
# 		"SITE_SECTION":"/search/index",
# 		"SITE_NAME":"검색",
# 		"PAGE_TYPE": "",
# 		"PAGE_PATH":"/search",
# 		"PAGE_NAME":"index",
# 	});
# })();
# </script>
# <input id="domainId" type="hidden" value="1101"/>
# <script src="https://rd.yna.co.kr/common/js/cp.js"></script>
# </body>
# </html>

# %%
news_tags = yh_soup.select('div.cts_atclst ul li')
for i in news_tags:
    print(i.select_one('a').get('href'))
